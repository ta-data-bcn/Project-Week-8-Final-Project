# %% [markdown]
# # Recency Frequency Monetary (RFM)

# %% [markdown]
# After having cleaned the data and reduced some features I wanted to start with the analysis. I set the goal to cluster the different customers to receive new insights. I started with the following questions:
# - Is there any significant difference between the customers of the different markets/countries.
# - There is loss/profit. How much profit did the store make in last few years?
# - Which are the valuable customers and do they still order products from our store?
#
# So those few questions lead me to the RFM concept that is build up by 3 factors:
# - Recency: How recently a customer has made a purchase
# - Frequency: How often a customer makes a purchase
# - Monetary: How much money a customer spends on purchases
# The RFM value is a marketing analysis tool used to identify a company's or an organization's best customers by using certain measures.

# %% [markdown]
# ### Import libaries and datasets

# %%
import numpy as np
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os
from sklearn.metrics import confusion_matrix, accuracy_score
sns.set()
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %%
df=pd.read_csv('../csv/cleaned_csv.csv')

# %%
df.head()
# Out:
#        Date Customer_ID    Customer_Name      Segment         City    Country  \
# 0  1/1/2011    TB-11280  Toby Braunhardt     Consumer  Constantine    Algeria
# 1  1/1/2011    JH-15985      Joseph Holt     Consumer  Wagga Wagga  Australia
# 2  1/1/2011      AT-735    Annie Thurman     Consumer     Budapest    Hungary
# 3  1/1/2011    EM-14140     Eugene Moren  Home Office    Stockholm     Sweden
# 4  1/1/2011    JH-15985      Joseph Holt     Consumer  Wagga Wagga  Australia
#
#    Market        Product_ID         Category Sub_Category  \
# 0  Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1    APAC   OFF-SU-10000618  Office Supplies     Supplies
# 2    EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3      EU   OFF-PA-10001492  Office Supplies        Paper
# 4    APAC   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product_Name    Sales  Quantity  Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300         2       0.0  106.140
# 1     Acme Trimmer, High Speed  120.366         3       0.1   36.036
# 2      Tenex Box, Single Width   66.120         4       0.0   29.640
# 3  Enermax Note Cards, Premium   44.865         3       0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670         5       0.1   37.770
#
#    Shipping Cost  Sales_ohne_Discount
# 0          35.46               408.30
# 1           9.72               133.74
# 2           8.17                66.12
# 3           4.82                89.73
# 4           4.70               126.30

# %%
df.dtypes
# Out:
# Date                    object
# Customer_ID             object
# Customer_Name           object
# Segment                 object
# City                    object
# Country                 object
# Market                  object
# Product_ID              object
# Category                object
# Sub_Category            object
# Product_Name            object
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# Shipping Cost          float64
# Sales_ohne_Discount    float64
# dtype: object

# %% [markdown]
# ## Frequency

# %% [markdown]
# The calculation of frequency is the easiest. Each order is one frequency. As we have not grouped the dataframe yet, we just give each order a 1.

# %%
df['Frequency']=np.where(df.Quantity>0,1,0)

# %% [markdown]
# ## Monetary

# %% [markdown]
# The monetary factor is also easy as long as we have it split up by orders. At the moment each sales value is equal to the monetary. Thoungh once we group the dataframe by customer, the monetary factor will represent the total of all sales.

# %%
df['Monetary']=df.Sales

# %% [markdown]
# ## Recency

# %% [markdown]
# Recency is the most trickiest one. It represents how recent a customer has ordered something from the store. In case he ordered already a few times, we only take the most recent order date. As datetime is a difficult format we rather convert it to days. But firstwe need to convert the date into a datetime format, so we can subtract dates to receive the amount of days.

# %%
from datetime import datetime as dt
df['Date']=pd.to_datetime(df['Date'])

# %% [markdown]
# What is the last date that was registered in the dataframe. It is the last day in 2014. Therefore we will take the 31st December 2014 as our last day in the timeframe. So we will subtract the most frequent order from that date to measure the recency.

# %%
last_date=df.Date.max()
print(last_date)
# Out:
# 2014-12-31 00:00:00

# %%
df.Date.min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
def recency_days(last_date,row):
    '''input: the date when the order was done, subtracting from the last date registered in the dataframe
    output: difference in days'''
    return abs((last_date - row['Date']).days)

# %%
df['Recency']=df.apply(lambda row:recency_days(last_date,row), axis=1)

# %%
df.head()
# Out:
#         Date Customer_ID    Customer_Name      Segment         City  \
# 0 2011-01-01    TB-11280  Toby Braunhardt     Consumer  Constantine
# 1 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
# 2 2011-01-01      AT-735    Annie Thurman     Consumer     Budapest
# 3 2011-01-01    EM-14140     Eugene Moren  Home Office    Stockholm
# 4 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
#
#      Country  Market        Product_ID         Category Sub_Category  \
# 0    Algeria  Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1  Australia    APAC   OFF-SU-10000618  Office Supplies     Supplies
# 2    Hungary    EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3     Sweden      EU   OFF-PA-10001492  Office Supplies        Paper
# 4  Australia    APAC   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product_Name    Sales  Quantity  Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300         2       0.0  106.140
# 1     Acme Trimmer, High Speed  120.366         3       0.1   36.036
# 2      Tenex Box, Single Width   66.120         4       0.0   29.640
# 3  Enermax Note Cards, Premium   44.865         3       0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670         5       0.1   37.770
#
#    Shipping Cost  Sales_ohne_Discount  Frequency  Monetary  Recency
# 0          35.46               408.30          1   408.300     1460
# 1           9.72               133.74          1   120.366     1460
# 2           8.17                66.12          1    66.120     1460
# 3           4.82                89.73          1    44.865     1460
# 4           4.70               126.30          1   113.670     1460

# %% [markdown]
# So we added the recency, frequency and monetary to the dataframe. Although before clustering the customers by RFM we will do the exploratory data analysis.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In a first step we want to see how the business has developed in the last few years. Therefore we need to group the dataset by date-month.

# %%
df.columns
# Out:
# Index(['Date', 'Customer_ID', 'Customer_Name', 'Segment', 'City', 'Country',
#        'Market', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Sales_ohne_Discount', 'Frequency', 'Monetary', 'Recency'],
#       dtype='object')

# %%
def monthly(x):
    return dt(x.year,x.month,1)
df['BillMonth']=df['Date'].apply(monthly)

# %%
df.head()
# Out:
#         Date Customer_ID    Customer_Name      Segment         City  \
# 0 2011-01-01    TB-11280  Toby Braunhardt     Consumer  Constantine
# 1 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
# 2 2011-01-01      AT-735    Annie Thurman     Consumer     Budapest
# 3 2011-01-01    EM-14140     Eugene Moren  Home Office    Stockholm
# 4 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
#
#      Country  Market        Product_ID         Category Sub_Category  ...  \
# 0    Algeria  Africa  OFF-TEN-10000025  Office Supplies      Storage  ...
# 1  Australia    APAC   OFF-SU-10000618  Office Supplies     Supplies  ...
# 2    Hungary    EMEA  OFF-TEN-10001585  Office Supplies      Storage  ...
# 3     Sweden      EU   OFF-PA-10001492  Office Supplies        Paper  ...
# 4  Australia    APAC   FUR-FU-10003447        Furniture  Furnishings  ...
#
#      Sales  Quantity  Discount   Profit  Shipping Cost  Sales_ohne_Discount  \
# 0  408.300         2       0.0  106.140          35.46               408.30
# 1  120.366         3       0.1   36.036           9.72               133.74
# 2   66.120         4       0.0   29.640           8.17                66.12
# 3   44.865         3       0.5  -26.055           4.82                89.73
# 4  113.670         5       0.1   37.770           4.70               126.30
#
#    Frequency  Monetary  Recency  BillMonth
# 0          1   408.300     1460 2011-01-01
# 1          1   120.366     1460 2011-01-01
# 2          1    66.120     1460 2011-01-01
# 3          1    44.865     1460 2011-01-01
# 4          1   113.670     1460 2011-01-01
#
# [5 rows x 21 columns]

# %%
date_profit=df.groupby('BillMonth', as_index=False).agg({'Profit':'sum'})
date_profit.columns
# Out:
# Index(['BillMonth', 'Profit'], dtype='object')

# %%
plt.figure(figsize=(16,7))
sns.lineplot(x=date_profit.BillMonth, y=date_profit.Profit)
plt.xlabel('Time')
plt.show()
# Out:
# /Users/kforster/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
most_selling_products=df.groupby('Product_Name', as_index=False).agg({'Quantity':'sum'}).sort_values(by='Quantity', ascending=False).head(20)
plt.figure(figsize=(18,9))
sns.set_context('talk')
sns.barplot(x=most_selling_products.Quantity,y=most_selling_products.Product_Name, palette="tab20c_r")
plt.xticks(np.arange(0,900,50),rotation = 90)
plt.xlabel("Amount")
plt.ylabel("Product")
plt.title("Most Selling 20 Products")
# Out:
# Text(0.5, 1.0, 'Most Selling 20 Products')

# %% [markdown]
# ## Cohort analysis

# %%
g=df.groupby('Customer_ID')['BillMonth']
df['CohortMonth']=g.transform('min')
df.head()
# Out:
#         Date Customer_ID    Customer_Name      Segment         City  \
# 0 2011-01-01    TB-11280  Toby Braunhardt     Consumer  Constantine
# 1 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
# 2 2011-01-01      AT-735    Annie Thurman     Consumer     Budapest
# 3 2011-01-01    EM-14140     Eugene Moren  Home Office    Stockholm
# 4 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
#
#      Country  Market        Product_ID         Category Sub_Category  ...  \
# 0    Algeria  Africa  OFF-TEN-10000025  Office Supplies      Storage  ...
# 1  Australia    APAC   OFF-SU-10000618  Office Supplies     Supplies  ...
# 2    Hungary    EMEA  OFF-TEN-10001585  Office Supplies      Storage  ...
# 3     Sweden      EU   OFF-PA-10001492  Office Supplies        Paper  ...
# 4  Australia    APAC   FUR-FU-10003447        Furniture  Furnishings  ...
#
#   Quantity  Discount   Profit  Shipping Cost  Sales_ohne_Discount  Frequency  \
# 0        2       0.0  106.140          35.46               408.30          1
# 1        3       0.1   36.036           9.72               133.74          1
# 2        4       0.0   29.640           8.17                66.12          1
# 3        3       0.5  -26.055           4.82                89.73          1
# 4        5       0.1   37.770           4.70               126.30          1
#
#    Monetary  Recency  BillMonth  CohortMonth
# 0   408.300     1460 2011-01-01   2011-01-01
# 1   120.366     1460 2011-01-01   2011-01-01
# 2    66.120     1460 2011-01-01   2011-01-01
# 3    44.865     1460 2011-01-01   2011-01-01
# 4   113.670     1460 2011-01-01   2011-01-01
#
# [5 rows x 22 columns]

# %%
df.CohortMonth.value_counts()
# Out:
# 2011-01-01    11660
# 2011-03-01     7551
# 2011-02-01     7029
# 2011-04-01     4676
# 2011-06-01     4079
# 2011-05-01     3962
# 2011-08-01     2450
# 2011-07-01     2254
# 2011-09-01     1750
# 2011-10-01     1211
# 2011-11-01      962
# 2011-12-01      653
# 2012-06-01      311
# 2012-01-01      289
# 2012-02-01      289
# 2012-03-01      282
# 2012-09-01      255
# 2012-08-01      212
# 2012-07-01      176
# 2012-11-01      170
# 2012-05-01      145
# 2012-04-01      133
# 2012-12-01      126
# 2012-10-01       90
# 2013-01-01       81
# 2013-03-01       76
# 2013-06-01       62
# 2013-02-01       58
# 2013-04-01       55
# 2013-08-01       43
# 2014-01-01       27
# 2013-05-01       21
# 2013-12-01       20
# 2013-07-01       19
# 2014-02-01       19
# 2013-09-01       17
# 2014-07-01       15
# 2013-10-01       15
# 2014-06-01       14
# 2014-05-01       11
# 2014-04-01        8
# 2014-10-01        6
# 2014-03-01        5
# 2013-11-01        2
# Name: CohortMonth, dtype: int64

# %%
def get_int (df,column):
    year=df[column].dt.year
    month=df[column].dt.month
    return year, month

billYear, billMonth=get_int(df,'BillMonth')
cohortYear, cohortMonth = get_int(df,'CohortMonth')

diffYear=billYear - cohortYear
diffMonth=billMonth-cohortMonth

df['Month_index']=diffYear *12+diffMonth+1
df.head()
# Out:
#         Date Customer_ID    Customer_Name      Segment         City  \
# 0 2011-01-01    TB-11280  Toby Braunhardt     Consumer  Constantine
# 1 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
# 2 2011-01-01      AT-735    Annie Thurman     Consumer     Budapest
# 3 2011-01-01    EM-14140     Eugene Moren  Home Office    Stockholm
# 4 2011-01-01    JH-15985      Joseph Holt     Consumer  Wagga Wagga
#
#      Country  Market        Product_ID         Category Sub_Category  ...  \
# 0    Algeria  Africa  OFF-TEN-10000025  Office Supplies      Storage  ...
# 1  Australia    APAC   OFF-SU-10000618  Office Supplies     Supplies  ...
# 2    Hungary    EMEA  OFF-TEN-10001585  Office Supplies      Storage  ...
# 3     Sweden      EU   OFF-PA-10001492  Office Supplies        Paper  ...
# 4  Australia    APAC   FUR-FU-10003447        Furniture  Furnishings  ...
#
#   Discount   Profit  Shipping Cost  Sales_ohne_Discount  Frequency  Monetary  \
# 0      0.0  106.140          35.46               408.30          1   408.300
# 1      0.1   36.036           9.72               133.74          1   120.366
# 2      0.0   29.640           8.17                66.12          1    66.120
# 3      0.5  -26.055           4.82                89.73          1    44.865
# 4      0.1   37.770           4.70               126.30          1   113.670
#
#    Recency  BillMonth  CohortMonth  Month_index
# 0     1460 2011-01-01   2011-01-01            1
# 1     1460 2011-01-01   2011-01-01            1
# 2     1460 2011-01-01   2011-01-01            1
# 3     1460 2011-01-01   2011-01-01            1
# 4     1460 2011-01-01   2011-01-01            1
#
# [5 rows x 23 columns]

# %%
df['CohortMonth']=df['CohortMonth'].apply(dt.date)

# %%
g=df.groupby(['CohortMonth','Month_index'])

cohortData=g['Customer_ID'].apply(pd.Series.nunique).reset_index()
cohortCounts=cohortData.pivot(index='CohortMonth', columns='Month_index', values='Customer_ID')
cohortSizes=cohortCounts.iloc[:,0]
retention=cohortCounts.divide(cohortSizes,axis=0)*100

retention.round(2)
# Out:
# Month_index     1       2      3       4       5       6       7       8   \
# CohortMonth
# 2011-01-01   100.0   21.80  28.95   23.31   21.05   28.20   27.44   26.32
# 2011-02-01   100.0   23.64  23.03   23.64   33.33   17.58   25.45   27.88
# 2011-03-01   100.0   20.43  14.52   28.49   19.89   25.27   31.18   26.88
# 2011-04-01   100.0   20.80  24.00   24.80   22.40   29.60   27.20   26.40
# 2011-05-01   100.0   25.24  18.45   32.04   28.16   23.30   28.16   27.18
# 2011-06-01   100.0   26.05  21.01   29.41   15.97   26.89   28.57   14.29
# 2011-07-01   100.0   18.75  20.31   28.12   26.56   29.69   10.94   15.62
# 2011-08-01   100.0   21.18  18.82   20.00   17.65   17.65   17.65   16.47
# 2011-09-01   100.0   16.00  18.67   21.33   13.33    9.33   13.33   12.00
# 2011-10-01   100.0   25.64  30.77   15.38    7.69   30.77   23.08   25.64
# 2011-11-01   100.0   27.50  22.50   15.00    7.50   15.00   35.00   17.50
# 2011-12-01   100.0    9.52   7.14    7.14    4.76   14.29    4.76    9.52
# 2012-01-01   100.0   25.00   5.00     NaN   10.00     NaN    5.00   10.00
# 2012-02-01   100.0   25.00  20.00    5.00   25.00   10.00   15.00   10.00
# 2012-03-01   100.0    9.52    NaN   14.29    4.76   23.81    4.76   23.81
# 2012-04-01   100.0     NaN   8.33    8.33   16.67    8.33     NaN   16.67
# 2012-05-01   100.0   14.29    NaN   28.57   21.43     NaN   21.43    7.14
# 2012-06-01   100.0    7.41  14.81    7.41    7.41    7.41    7.41    7.41
# 2012-07-01   100.0   14.29  14.29   14.29   21.43     NaN    7.14     NaN
# 2014-04-01     NaN    NaN    NaN    NaN
# 2014-05-01     NaN    NaN    NaN    NaN
# 2014-06-01     NaN    NaN    NaN    NaN
# 2014-07-01     NaN    NaN    NaN    NaN
# 2014-10-01     NaN    NaN    NaN    NaN
#
# [44 rows x 48 columns]

# %%
month_list = ["Jan '11", "Feb '11", "Mar '11", "Apr '11", "May '11", "Jun '11", "Jul '11", "Aug '11", "Sep '11", "Oct '11", "Nov '11", "Dec '11","Jan '12", "Feb '12", "Mar '12", "Apr '12", "May '12", "Jun '12"]
plt.figure(figsize=(20,10))
plt.title('Retention by Monthly Cohorts',size=25)
sns.heatmap(retention.iloc[:18,30:].round(2),annot=True, cmap='Blues',vmax=list(retention.max().sort_values(ascending=False))[1]+3, fmt='.1f', linewidth = 0.3,yticklabels=month_list)
plt.ylabel('Cohort Month')
plt.xlabel('Months after first order')
plt.show()

# %% [markdown]
# ## Cohort analysis EMEA

# %%
df_market=df[df.Market=='EMEA']

# %%
g=df_market.groupby('Customer_ID')['BillMonth']
df_market['CohortMonth']=g.transform('min')
df_market.head()

def get_int (df_market,column):
    year=df_market[column].dt.year
    month=df_market[column].dt.month
    return year, month

billYear, billMonth=get_int(df_market,'BillMonth')
cohortYear, cohortMonth = get_int(df_market,'CohortMonth')

diffYear=billYear - cohortYear
diffMonth=billMonth-cohortMonth

df_market['Month_index']=diffYear *12+diffMonth+1
df_market.head()
# Out:
# /Users/kforster/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/kforster/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#          Date Customer_ID    Customer_Name   Segment       City  Country  \
# 2  2011-01-01      AT-735    Annie Thurman  Consumer   Budapest  Hungary
# 12 2011-01-02     PO-8850  Patrick O'Brill  Consumer    Mashhad     Iran
# 25 2011-01-03     RD-9900      Ruben Dartt  Consumer  Vinnytsya  Ukraine
# 30 2011-01-03     RD-9900      Ruben Dartt  Consumer  Vinnytsya  Ukraine
# 33 2011-01-03     RD-9900      Ruben Dartt  Consumer  Vinnytsya  Ukraine
#
#    Market        Product_ID         Category Sub_Category  ... Discount  \
# 2    EMEA  OFF-TEN-10001585  Office Supplies      Storage  ...      0.0
# 12   EMEA  FUR-ADV-10002601        Furniture  Furnishings  ...      0.0
# 25   EMEA  TEC-LOG-10003896       Technology  Accessories  ...      0.0
# 30   EMEA  OFF-FEL-10002867  Office Supplies      Storage  ...      0.0
# 33   EMEA  TEC-SHA-10004874       Technology      Copiers  ...      0.0
#
#     Profit  Shipping Cost  Sales_ohne_Discount  Frequency  Monetary  Recency  \
# 2    29.64           8.17                66.12          1     66.12     1460
# 12  148.50          19.65               309.60          1    309.60     1459
# 25  264.60         146.55              1470.78          1   1470.78     1458
# 30  211.50          60.78              1244.16          1   1244.16     1458
# 33  123.36          42.88               587.70          1    587.70     1458
#
#     BillMonth  CohortMonth  Month_index
# 2  2011-01-01   2011-01-01            1
# 12 2011-01-01   2011-01-01            1
# 25 2011-01-01   2011-01-01            1
# 30 2011-01-01   2011-01-01            1
# 33 2011-01-01   2011-01-01            1
#
# [5 rows x 23 columns]

# %%
df_market['CohortMonth']=df_market['CohortMonth'].apply(dt.date)
# Out:
# /Users/kforster/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
g=df_market.groupby(['CohortMonth','Month_index'])

cohortData=g['Customer_ID'].apply(pd.Series.nunique).reset_index()
cohortCounts=cohortData.pivot(index='CohortMonth', columns='Month_index', values='Customer_ID')
cohortSizes=cohortCounts.iloc[:,0]
retention=cohortCounts.divide(cohortSizes,axis=0)*100

g=df_market.groupby(['CohortMonth','Month_index'])

cohortData=g['Customer_ID'].apply(pd.Series.nunique).reset_index()
cohortCounts=cohortData.pivot(index='CohortMonth', columns='Month_index', values='Customer_ID')
cohortSizes=cohortCounts.iloc[:,0]
retention=cohortCounts.divide(cohortSizes,axis=0)*100

retention.round(2)
# Out:
# Month_index     1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2011-01-01   100.0   3.45   3.45   3.45    NaN  13.79   6.90   3.45    NaN
# 2011-02-01   100.0    NaN    NaN    NaN  10.00    NaN  10.00  10.00   5.00
# 2011-03-01   100.0  13.79    NaN   3.45    NaN  10.34    NaN   3.45    NaN
# 2011-04-01   100.0   4.00   4.00    NaN  12.00    NaN    NaN   4.00   4.00
# 2011-05-01   100.0    NaN    NaN    NaN    NaN   4.17   8.33   4.17  12.50
# 2011-06-01   100.0   2.38   9.52   2.38   4.76    NaN   4.76    NaN   7.14
# 2011-07-01   100.0  14.81   3.70  11.11    NaN   3.70    NaN   3.70    NaN
# 2011-08-01   100.0    NaN   8.57   2.86   2.86    NaN   5.71   5.71    NaN
# 2011-09-01   100.0    NaN   2.44   4.88   4.88   7.32   7.32   4.88   2.44
# 2011-10-01   100.0    NaN   9.09   9.09    NaN  18.18    NaN    NaN    NaN
# 2011-11-01   100.0    NaN  14.29   4.76  14.29    NaN   4.76   4.76   4.76
# 2011-12-01   100.0    NaN   4.00   8.00    NaN    NaN   4.00   4.00   4.00
# 2012-01-01   100.0  10.53   5.26   5.26  10.53   5.26    NaN   5.26   5.26
# 2012-02-01   100.0   6.25   6.25    NaN    NaN  12.50  12.50  18.75    NaN
# 2012-03-01   100.0  12.50    NaN  18.75   6.25  12.50  12.50  12.50   6.25
# 2012-04-01   100.0   7.69  23.08    NaN   7.69    NaN    NaN  23.08   7.69
# 2012-05-01   100.0  13.33    NaN   6.67   6.67    NaN  13.33  20.00    NaN
# 2012-06-01   100.0   3.45  13.79   3.45   3.45   3.45   6.90   3.45    NaN
# 2012-07-01   100.0   8.33   8.33  16.67  16.67    NaN    NaN   8.33   8.33
# 2012-08-01   100.0   6.90   3.45   3.45    NaN  10.34   3.45  10.34   6.90
# 2012-09-01   100.0    NaN   6.25  12.50   6.25  12.50  12.50    NaN   6.25
# 2012-10-01   100.0   9.09    NaN    NaN   9.09    NaN   9.09    NaN  18.18
# 2012-11-01   100.0    NaN   5.26   5.26   5.26   5.26   5.26   5.26    NaN
# 2012-12-01   100.0    NaN   4.55   9.09   4.55   4.55   4.55    NaN   4.55
# 2013-01-01   100.0  10.00  10.00    NaN    NaN    NaN    NaN  10.00    NaN
# 2013-02-01   100.0    NaN    NaN    NaN    NaN    NaN  12.50    NaN    NaN
# 2013-03-01   100.0    NaN    NaN    NaN    NaN    NaN    NaN    Na
...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-07-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-08-01    3.45  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-09-01   12.50  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-10-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-11-01   15.79  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2012-12-01   18.18  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-01-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-02-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-03-01   18.18  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-04-01   11.11  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-05-01    5.88  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-06-01    5.88  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-07-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-08-01   23.08  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-09-01   13.33  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-10-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-11-01   16.67  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2013-12-01    6.25  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-01-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-02-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-03-01   12.50  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-04-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-05-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-06-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-07-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-08-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-09-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-10-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-11-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2014-12-01     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# Month_index     46     47    48
# CohortMonth
# 2011-01-01   10.34  10.34  3.45
# 2011-02-01     NaN  15.00   NaN
# 2011-03-01   17.24    NaN   NaN
# 2011-04-01     NaN    NaN   NaN
# 2011-05-01     NaN    NaN   NaN
# 2011-06-01     NaN    NaN   NaN
# 2011-07-01     NaN    NaN   NaN
# 2011-08-01     NaN    NaN   NaN
# 2011-09-01     NaN    NaN   NaN
# 2011-10-01     NaN    NaN   NaN
# 2011-11-01     NaN    NaN   NaN
# 2011-12-01     NaN    NaN   NaN
# 2012-01-01     NaN    NaN   NaN
# 2012-02-01     NaN    NaN   NaN
# 2012-03-01     NaN    NaN   NaN
# 2012-04-01     NaN    NaN   NaN
# 2012-05-01     NaN    NaN   NaN
# 2012-06-01     NaN    NaN   NaN
# 2012-07-01     NaN    NaN   NaN
# 2012-08-01     NaN    NaN   NaN
# 2012-09-01     NaN    NaN   NaN
# 2012-10-01     NaN    NaN   NaN
# 2012-11-01     NaN    NaN   NaN
# 2012-12-01     NaN    NaN   NaN
# 2013-01-01     NaN    NaN   NaN
# 2013-02-01     NaN    NaN   NaN
# 2013-03-01     NaN    NaN   NaN
# 2013-04-01     NaN    NaN   NaN
# 2013-05-01     NaN    NaN   NaN
# 2013-06-01     NaN    NaN   NaN
# 2013-07-01     NaN    NaN   NaN
# 2013-08-01     NaN    NaN   NaN
# 2013-09-01     NaN    NaN   NaN
# 2013-10-01     NaN    NaN   NaN
# 2013-11-01     NaN    NaN   NaN
# 2013-12-01     NaN    NaN   NaN
# 2014-01-01     NaN    NaN   NaN
# 2014-02-01     NaN    NaN   NaN
# 2014-03-01     NaN    NaN   NaN
# 2014-04-01     NaN    NaN   NaN
# 2014-05-01     NaN    NaN   NaN
# 2014-06-01     NaN    NaN   NaN
# 2014-07-01     NaN    NaN   NaN
# 2014-08-01     NaN    NaN   NaN
# 2014-09-01     NaN    NaN   NaN
# 2014-10-01     NaN    NaN   NaN
# 2014-11-01     NaN    NaN   NaN
# 2014-12-01     NaN    NaN   NaN
#
# [48 rows x 48 columns]

# %%
month_list = ["Jan '11", "Feb '11", "Mar '11", "Apr '11", "May '11", "Jun '11", "Jul '11", "Aug '11", "Sep '11", "Oct '11", "Nov '11", "Dec '11","Jan '12", "Feb '12", "Mar '12", "Apr '12", "May '12", "Jun '12"]
plt.figure(figsize=(20,10))
plt.title('Retention by Monthly Cohorts')
sns.heatmap(retention.iloc[:18,30:].round(2),annot=True, cmap='Blues',vmax=list(retention.max().sort_values(ascending=False))[1]+3, fmt='.1f', linewidth = 0.3,yticklabels=month_list)
plt.show()

# %% [markdown]
# ## RFM

# %%
df_RFM=df.groupby(['Customer_ID','Customer_Name'], as_index=False).agg({'Frequency':'sum','Recency':'min','Monetary':'sum','Profit':'sum'})
df_RFM2=df_RFM
df_RFM
# Out:
#      Customer_ID         Customer_Name  Frequency  Recency     Monetary  \
# 0       AA-10315            Alex Avila         42        8  13747.41300
# 1       AA-10375          Allen Armold         42        6   5884.19500
# 2       AA-10480          Andrew Allen         38      117  17695.58978
# 3       AA-10645         Anna Andreadi         73       26  15343.89070
# 4         AA-315            Alex Avila          8        2   2243.25600
# 5         AA-375          Allen Armold         13      181    654.49200
# 6         AA-480          Andrew Allen         10      314   2063.49300
# 7         AA-645         Anna Andreadi         18       81   1968.32400
# 8       AB-10015         Aaron Bergman         77       16  20037.49750
# 9       AB-10060       Adam Bellavance         57       25  18416.55040
# 10      AB-10105         Adrian Barton         62       32  22966.78000
# 11      AB-10150           Aimee Bixby         47       22  13057.29460
# 12      AB-10165           Alan Barnes         52       13  11649.26500
# 13      AB-10255  Alejandro Ballentine         53        5  10786.71640
# 14        AB-105         Adrian Barton         15       43   2156.40000
# 15      AB-10600             Ann Blume         38       50  13318.66310
# 16         AB-15         Aaron Bergman         12      412   4607.13000
# 17        AB-150           Aimee Bixby          8      398   3143.88000
# 18        AB-165           Alan Barnes          8       16   1399.77600
# 19        AB-255  Alejandro Ballentine         15       43   4679.50200
# 20         AB-60       Adam Bellavance         11       35   1770.22800
# 21        AB-600             Ann Blume         26        7   5408.55000
# 22      AC-10420         Alyssa Crouse         40        6  10607.69470
# 23      AC-10450               Amy Cox         29        5  16126.39040
# 24      AC-10615             Ann Chong         65        6  12729.72448
# 25      AC-10660            Anna Chung         35        2   6255.61908
# 26        AC-420         Alyssa Crouse         21       13   1689.67500
# 27        AC-450               Amy Cox         10      116   1026.59700
# 28        AC-615             Ann Chong         18       92   2298.43200
# 29        AC-660            Anna Chung          8      297   2676.09000
# ...          ...                   ...        ...      ...          ...
# 1560    VG-11790        Vivek Gonzalez          7      160    386.17200
# 1561    VG-11805           Vivek Grady          7      135   1190.22000
# 1562    VG-21790        Vivek Gonzalez         43       22   9908.60650
# 1563    VG-21805           Vivek Grady         54        2  22573.37116
# 1564    VM-11685       Valerie Mitchum         14       13    858.97800
# 1565    VM-11835         Vivian Mathis          7        8   1270.41000
# 1566    VM-21685       Valerie Mitchum         54       32  13708.12232
# 1567    VM-21835         Vivian Mathis         29       52   2621.81700
# 1568    VP-11730          Victor Preis          9      162    432.00000
# 1569    VP-11760      Victoria Pisteka          9      117   1615.66200
# 1570    VP-21730          Victor Preis         49       40  11629.26900
# 1571    VP-21760      Victoria Pisteka         51       75  16935.56350
# 1572    VS-11820      Vivek Sundaresam         11      110   1136.21400
# 1573    VS-21820      Vivek Sundaresam         29       87  10275.77500
# 1574    VT-11700      Valerie Takahito         11      125   1271.44200
# 1575    VT-21700      Valerie Takahito         61        7  18099.30610
# 1576    VW-11775       Victoria Wilson          9        7   1253.16600
# 1577    VW-21775       Victoria Wilson         57        6  15785.37740
# 1578    WB-11850         William Brown          5      144    182.53200
# 1579    WB-21850         William Brown         79       20  16704.66120
# 1580    XP-11865          Xylona Preis          6      160   1011.79800
# 1581    XP-21865          Xylona Preis         55       43  11187.15260
# 1582    YC-11895        Yoseph Carroll          5       99    166.29900
# 1583    YC-21895        Yoseph Carroll         51        4  19998.07860
# 1584    YS-11880         Yana Sorensen          8        4   1328.83200
# 1585    YS-21880         Yana Sorensen         54        9  18703.60600
# 1586    ZC-11910      Zuschuss Carroll          1      200      7.17300
# 1587    ZC-21910      Zuschuss Carroll         84        3  28472.81926
# 1588    ZD-11925    Zuschuss Donatelli         18        3   2951.22600
# 1589    ZD-21925    Zuschuss Donatelli         36        1   9479.34440
#
#           Profit
# 0      447.69050
# 1      677.47740
# 2     1516.47518
# 3     3051.43900
# 4      535.56600
# 5       77.44200
# 6      554.61300
# 7     -608.34600
# 8     3719.48800
# 9     4514.05890
# 10    6912.61450
# 11    2064.21430
# 12    2329.47000
# 13     -43.23810
# 14    -495.33000
# 15     905.36070
# 16     963.72000
# 17     862.14000
# 18     106.59600
# 19     801.85200
# 20     465.91800
# 21     964.65000
# 22     206.48050
# 23    4105.60420
# 24    1160.67578
# 25    -998.99732
# 26     237.55500
# 27    -125.19300
# 28    -280.54800
# 29     726.87000
# ...          ...
# 1560    47.44200
# 1561   140.31000
# 1562  -411.86670
# 1563  3906.59616
# 1564   -94.96200
# 1565   338.07000
# 1566 -1550.83678
# 1567   318.84430
# 1568  -508.41000
# 1569   374.71200
# 1570  2741.20580
# 1571  2016.15070
# 1572   126.53400
# 1573  1460.08470
# 1574   178.57200
# 1575   912.21120
# 1576   252.48600
# 1577    41.89490
# 1578  -146.59800
# 1579  2694.50030
# 1580    65.14800
# 1581  1239.57460
# 1582    22.26900
# 1583  4324.90760
# 1584   358.81200
# 1585  3091.59430
# 1586   -15.56700
# 1587   452.50326
# 1588   478.41600
# 1589  -276.67890
#
# [1590 rows x 6 columns]

# %%
df_RFM['Frequency_qcut']=pd.qcut(df_RFM['Frequency'],q=5, labels = ['1','2','3','4','5'])

# %%
df_RFM['Recency_qcut']=pd.qcut(df_RFM['Recency'],q=5, labels = ['5','4','3','2','1'])
df_RFM['Monetary_qcut']=pd.qcut(df_RFM['Monetary'],q=5, labels = ['1','2','3','4','5'])

# %%
df_RFM.head()
# Out:
#   Customer_ID  Customer_Name  Frequency  Recency     Monetary      Profit  \
# 0    AA-10315     Alex Avila         42        8  13747.41300   447.69050
# 1    AA-10375   Allen Armold         42        6   5884.19500   677.47740
# 2    AA-10480   Andrew Allen         38      117  17695.58978  1516.47518
# 3    AA-10645  Anna Andreadi         73       26  15343.89070  3051.43900
# 4      AA-315     Alex Avila          8        2   2243.25600   535.56600
#
#   Frequency_qcut Recency_qcut Monetary_qcut
# 0              4            5             4
# 1              4            5             3
# 2              3            2             5
# 3              5            4             5
# 4              1            5             2

# %%
df_RFM['Frequency_qcut'] = pd.to_numeric(df_RFM['Frequency_qcut'])
df_RFM['Recency_qcut'] = pd.to_numeric(df_RFM['Recency_qcut'])
df_RFM['Monetary_qcut'] = pd.to_numeric(df_RFM['Monetary_qcut'])

# %%
df_RFM['Total_score']=df_RFM.Frequency_qcut+df_RFM.Monetary_qcut+df_RFM.Recency_qcut

# %%
df_RFM.head()
# Out:
#   Customer_ID  Customer_Name  Frequency  Recency     Monetary      Profit  \
# 0    AA-10315     Alex Avila         42        8  13747.41300   447.69050
# 1    AA-10375   Allen Armold         42        6   5884.19500   677.47740
# 2    AA-10480   Andrew Allen         38      117  17695.58978  1516.47518
# 3    AA-10645  Anna Andreadi         73       26  15343.89070  3051.43900
# 4      AA-315     Alex Avila          8        2   2243.25600   535.56600
#
#    Frequency_qcut  Recency_qcut  Monetary_qcut  Total_score
# 0               4             5              4           13
# 1               4             5              3           12
# 2               3             2              5           10
# 3               5             4              5           14
# 4               1             5              2            8

# %%
df_RFM.max()
# Out:
# Customer_ID                 ZD-21925
# Customer_Name     Zuschuss Donatelli
# Frequency                         97
# Recency                         1118
# Monetary                     35668.1
# Profit                       8787.47
# Frequency_qcut                     5
# Recency_qcut                       5
# Monetary_qcut                      5
# Total_score                       15
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df_RFM.Monetary, y=df_RFM.Profit, hue=df_RFM.Total_score)
plt.xlabel('Total sales in $')
# Out:
# Text(0.5, 0, 'Total sales in $')

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df_RFM.Frequency, y=df_RFM.Profit, hue=df_RFM.Total_score)
plt.xlabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
df_RFM.drop(['Total_score','Customer_Name', 'Frequency', 'Recency', 'Monetary','Profit'], axis=1, inplace=True)

# %%
df_RFM.set_index('Customer_ID',inplace=True)

# %%
df_RFM.dtypes
# Out:
# Frequency_qcut    int64
# Recency_qcut      int64
# Monetary_qcut     int64
# dtype: object

# %%
wcss = []

for i in range(1, 10):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df_RFM)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 10), wcss, 'bx-')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
kmeans = KMeans(n_clusters=3).fit(df_RFM)
df_RFM['label'] = kmeans.fit_predict(df_RFM)

# %%
df_RFM
# Out:
#              Frequency_qcut  Recency_qcut  Monetary_qcut  label
# Customer_ID
# AA-10315                  4             5              4      2
# AA-10375                  4             5              3      2
# AA-10480                  3             2              5      2
# AA-10645                  5             4              5      2
# AA-315                    1             5              2      0
# AA-375                    2             1              1      1
# AA-480                    1             1              2      1
# AA-645                    3             2              2      1
# AB-10015                  5             4              5      2
# AB-10060                  5             4              5      2
# AB-10105                  5             3              5      2
# AB-10150                  4             4              4      2
# AB-10165                  4             4              4      2
# AB-10255                  4             5              4      2
# AB-105                    2             3              2      0
# AB-10600                  3             3              4      2
# AB-15                     2             1              3      1
# AB-150                    1             1              2      1
# AB-165                    1             4              2      0
# AB-255                    2             3              3      0
# AB-60                     1             3              2      1
# AB-600                    3             5              3      0
# AC-10420                  3             5              4      2
# AC-10450                  3             5              5      2
# AC-10615                  5             5              4      2
# AC-10660                  3             5              3      0
# AC-420                    3             4              2      0
# AC-450                    1             2              1      1
# AC-615                    3             2              2      1
# AC-660                    1             1              2      1
# ...                     ...           ...            ...    ...
# VG-11790                  1             1              1      1
# VG-11805                  1             1              1      1
# VG-21790                  4             4              4      2
# VG-21805                  4             5              5      2
# VM-11685                  2             4              1      0
# VM-11835                  1             5              1      0
# VM-21685                  4             3              4      2
# VM-21835                  3             3              2      0
# VP-11730                  1             1              1      1
# VP-11760                  1             2              2      1
# VP-21730                  4             3              4      2
# VP-21760                  4             2              5      2
# VS-11820                  1             2              1      1
# VS-21820                  3             2              4      2
# VT-11700                  1             2              1      1
# VT-21700                  5             5              5      2
# VW-11775                  1             5              1      0
# VW-21775                  5             5              5      2
# WB-11850                  1             1              1      1
# WB-21850                  5             4              5      2
# XP-11865                  1             1              1      1
# XP-21865                  4             3              4      2
# YC-11895                  1             2              1      1
# YC-21895                  4             5              5      2
# YS-11880                  1             5              1      0
# YS-21880                  4             5              5      2
# ZC-11910                  1             1              1      1
# ZC-21910                  5             5              5      2
# ZD-11925                  3             5              2      0
# ZD-21925                  3             5              3      0
#
# [1590 rows x 4 columns]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_RFM.Frequency_qcut[df_RFM.label == 0], df_RFM["Recency_qcut"][df_RFM.label == 0], df_RFM["Monetary_qcut"][df_RFM.label == 0], c='blue', s=60)
ax.scatter(df_RFM.Frequency_qcut[df_RFM.label == 1], df_RFM["Recency_qcut"][df_RFM.label == 1], df_RFM["Monetary_qcut"][df_RFM.label == 1], c='red', s=60)
ax.scatter(df_RFM.Frequency_qcut[df_RFM.label == 2], df_RFM["Recency_qcut"][df_RFM.label == 2], df_RFM["Monetary_qcut"][df_RFM.label == 2], c='green', s=60)
ax.view_init(30, 185)
plt.xlabel("Frequency")
plt.ylabel("Recency")
ax.set_zlabel('Monetary')
plt.show()

# %%
df_RFM.reset_index(inplace=True)
df_RFM
# Out:
#      Customer_ID  Frequency_qcut  Recency_qcut  Monetary_qcut  label
# 0       AA-10315               4             5              4      2
# 1       AA-10375               4             5              3      2
# 2       AA-10480               3             2              5      2
# 3       AA-10645               5             4              5      2
# 4         AA-315               1             5              2      0
# 5         AA-375               2             1              1      1
# 6         AA-480               1             1              2      1
# 7         AA-645               3             2              2      1
# 8       AB-10015               5             4              5      2
# 9       AB-10060               5             4              5      2
# 10      AB-10105               5             3              5      2
# 11      AB-10150               4             4              4      2
# 12      AB-10165               4             4              4      2
# 13      AB-10255               4             5              4      2
# 14        AB-105               2             3              2      0
# 15      AB-10600               3             3              4      2
# 16         AB-15               2             1              3      1
# 17        AB-150               1             1              2      1
# 18        AB-165               1             4              2      0
# 19        AB-255               2             3              3      0
# 20         AB-60               1             3              2      1
# 21        AB-600               3             5              3      0
# 22      AC-10420               3             5              4      2
# 23      AC-10450               3             5              5      2
# 24      AC-10615               5             5              4      2
# 25      AC-10660               3             5              3      0
# 26        AC-420               3             4              2      0
# 27        AC-450               1             2              1      1
# 28        AC-615               3             2              2      1
# 29        AC-660               1             1              2      1
# ...          ...             ...           ...            ...    ...
# 1560    VG-11790               1             1              1      1
# 1561    VG-11805               1             1              1      1
# 1562    VG-21790               4             4              4      2
# 1563    VG-21805               4             5              5      2
# 1564    VM-11685               2             4              1      0
# 1565    VM-11835               1             5              1      0
# 1566    VM-21685               4             3              4      2
# 1567    VM-21835               3             3              2      0
# 1568    VP-11730               1             1              1      1
# 1569    VP-11760               1             2              2      1
# 1570    VP-21730               4             3              4      2
# 1571    VP-21760               4             2              5      2
# 1572    VS-11820               1             2              1      1
# 1573    VS-21820               3             2              4      2
# 1574    VT-11700               1             2              1      1
# 1575    VT-21700               5             5              5      2
# 1576    VW-11775               1             5              1      0
# 1577    VW-21775               5             5              5      2
# 1578    WB-11850               1             1              1      1
# 1579    WB-21850               5             4              5      2
# 1580    XP-11865               1             1              1      1
# 1581    XP-21865               4             3              4      2
# 1582    YC-11895               1             2              1      1
# 1583    YC-21895               4             5              5      2
# 1584    YS-11880               1             5              1      0
# 1585    YS-21880               4             5              5      2
# 1586    ZC-11910               1             1              1      1
# 1587    ZC-21910               5             5              5      2
# 1588    ZD-11925               3             5              2      0
# 1589    ZD-21925               3             5              3      0
#
# [1590 rows x 5 columns]

# %%
df.dtypes
# Out:
# Date                   datetime64[ns]
# Customer_ID                    object
# Customer_Name                  object
# Segment                        object
# City                           object
# Country                        object
# Market                         object
# Product_ID                     object
# Category                       object
# Sub_Category                   object
# Product_Name                   object
# Sales                         float64
# Quantity                        int64
# Discount                      float64
# Profit                        float64
# Shipping Cost                 float64
# Sales_ohne_Discount           float64
# Frequency                       int64
# Monetary                      float64
# Recency                         int64
# BillMonth              datetime64[ns]
# CohortMonth                    object
# Month_index                     int64
# dtype: object

# %%
df_with_RFM=pd.merge(df,df_RFM, on="Customer_ID")
df_with_RFM.to_csv('../csv/DF_incl_RFM.csv', sep=",", index=False)

# %%
df_with_RFM.dtypes
# Out:
# Date                   datetime64[ns]
# Customer_ID                    object
# Customer_Name                  object
# Segment                        object
# City                           object
# Country                        object
# Market                         object
# Product_ID                     object
# Category                       object
# Sub_Category                   object
# Product_Name                   object
# Sales                         float64
# Quantity                        int64
# Discount                      float64
# Profit                        float64
# Shipping Cost                 float64
# Sales_ohne_Discount           float64
# Frequency                       int64
# Monetary                      float64
# Recency                         int64
# BillMonth              datetime64[ns]
# CohortMonth                    object
# Month_index                     int64
# Frequency_qcut                  int64
# Recency_qcut                    int64
# Monetary_qcut                   int64
# label                           int32
# dtype: object

# %%
df_with_RFM.head()
# Out:
#         Date Customer_ID    Customer_Name   Segment         City  Country  \
# 0 2011-01-01    TB-11280  Toby Braunhardt  Consumer  Constantine  Algeria
# 1 2011-02-14    TB-11280  Toby Braunhardt  Consumer       Kaluga   Russia
# 2 2012-08-14    TB-11280  Toby Braunhardt  Consumer       Bamako     Mali
# 3 2014-03-18    TB-11280  Toby Braunhardt  Consumer      Calgary   Canada
# 4 2014-03-18    TB-11280  Toby Braunhardt  Consumer      Calgary   Canada
#
#    Market        Product_ID         Category Sub_Category  ... Frequency  \
# 0  Africa  OFF-TEN-10000025  Office Supplies      Storage  ...         1
# 1    EMEA  OFF-SAN-10004881  Office Supplies          Art  ...         1
# 2  Africa  TEC-STA-10004536       Technology     Machines  ...         1
# 3  Canada  OFF-ELD-10001477  Office Supplies      Storage  ...         1
# 4  Canada  OFF-TEN-10004270  Office Supplies      Storage  ...         1
#
#    Monetary  Recency  BillMonth  CohortMonth  Month_index  Frequency_qcut  \
# 0    408.30     1460 2011-01-01   2011-01-01            1               2
# 1     27.09     1416 2011-02-01   2011-01-01            2               2
# 2    301.77      869 2012-08-01   2011-01-01           20               2
# 3    197.94      288 2014-03-01   2011-01-01           39               2
# 4    134.16      288 2014-03-01   2011-01-01           39               2
#
#    Recency_qcut  Monetary_qcut  label
# 0             1              2      1
# 1             1              2      1
# 2             1              2      1
# 3             1              2      1
# 4             1              2      1
#
# [5 rows x 27 columns]

# %%
df_with_RFM.columns
# Out:
# Index(['Date', 'Customer_ID', 'Customer_Name', 'Segment', 'City', 'Country',
#        'Market', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost',
#        'Sales_ohne_Discount', 'Frequency', 'Monetary', 'Recency', 'BillMonth',
#        'CohortMonth', 'Month_index', 'Frequency_qcut', 'Recency_qcut',
#        'Monetary_qcut', 'label'],
#       dtype='object')

# %%
df_with_RFM=df_with_RFM.astype({'Profit':'int64', 'Sales':'int64'},inplace=True)

# %%
df_with_RFM['Profit'].max()
# Out:
# 8399

# %%
df_with_RFM.corr()
# Out:
#                         Sales  Quantity  Discount    Profit  Shipping Cost  \
# Sales                1.000000  0.319234 -0.090096  0.505661       0.784406
# Quantity             0.319234  1.000000 -0.019912  0.104771       0.272653
# Discount            -0.090096 -0.019912  1.000000 -0.314752      -0.079057
# Profit               0.505661  0.104771 -0.314752  1.000000       0.354979
# Shipping Cost        0.784406  0.272653 -0.079057  0.354979       1.000000
# Sales_ohne_Discount  0.952240  0.318152  0.032957  0.274898       0.751169
# Frequency                 NaN       NaN       NaN       NaN            NaN
# Monetary             1.000000  0.319222 -0.090103  0.505668       0.784404
# Recency              0.001165  0.002347  0.005365 -0.000927       0.002238
# Month_index          0.014056  0.044700 -0.019739  0.006693       0.010140
# Frequency_qcut       0.066588  0.197450 -0.047076  0.031436       0.054052
# Recency_qcut         0.031466  0.092482 -0.029799  0.019953       0.025829
# Monetary_qcut        0.124856  0.220944 -0.071028  0.059402       0.103222
# label                0.076207  0.185696 -0.051213  0.036980       0.062330
#
#                      Sales_ohne_Discount  Frequency  Monetary   Recency  \
# Sales                           0.952240        NaN  1.000000  0.001165
# Quantity                        0.318152        NaN  0.319222  0.002347
# Discount                        0.032957        NaN -0.090103  0.005365
# Profit                          0.274898        NaN  0.505668 -0.000927
# Shipping Cost                   0.751169        NaN  0.784404  0.002238
# Sales_ohne_Discount             1.000000        NaN  0.952241  0.002229
# Frequency                            NaN        NaN       NaN       NaN
# Monetary                        0.952241        NaN  1.000000  0.001167
# Recency                         0.002229        NaN  0.001167  1.000000
# Month_index                     0.012774        NaN  0.014056 -0.934549
# Frequency_qcut                  0.063454        NaN  0.066598  0.005080
# Recency_qcut                    0.027731        NaN  0.031469 -0.053149
# Monetary_qcut                   0.118188        NaN  0.124864  0.003721
# label                           0.072500        NaN  0.076212  0.017335
#
#                      Month_index  Frequency_qcut  Recency_qcut  Monetary_qcut  \
# Sales                   0.014056        0.066588      0.031466       0.124856
# Quantity                0.044700        0.197450      0.092482       0.220944
# Discount               -0.019739       -0.047076     -0.029799      -0.071028
# Profit                  0.006693        0.031436      0.019953       0.059402
# Shipping Cost           0.010140        0.054052      0.025829       0.103222
# Sales_ohne_Discount     0.012774        0.063454      0.027731       0.118188
# Frequency                    NaN             NaN           NaN            NaN
# Monetary                0.014056        0.066598      0.031469       0.124864
# Recency                -0.934549        0.005080     -0.053149       0.003721
# Month_index             1.000000        0.163573      0.116106       0.156036
# Frequency_qcut          0.163573        1.000000      0.357014       0.836385
# Recency_qcut            0.116106        0.357014      1.000000       0.338729
# Monetary_qcut           0.156036        0.836385      0.338729       1.000000
# label                   0.114563        0.708876      0.159198       0.723319
#
#                         label
# Sales                0.076207
# Quantity             0.185696
# Discount            -0.051213
# Profit               0.036980
# Shipping Cost        0.062330
# Sales_ohne_Discount  0.072500
# Frequency                 NaN
# Monetary             0.076212
# Recency              0.017335
# Month_index          0.114563
# Frequency_qcut       0.708876
# Recency_qcut         0.159198
# Monetary_qcut        0.723319
# label                1.000000

# %%
df_with_RFM.drop(['Date', 'Customer_Name', 'Segment', 'City', 'Country','Market', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name', 'Discount','Shipping Cost', 'Sales_ohne_Discount', 'Frequency_qcut', 'Recency_qcut','Monetary_qcut'], axis=1, inplace=True)

# %%
df_with_RFM
# Out:
#       Customer_ID  Sales  Quantity  Profit  Frequency   Monetary  Recency  \
# 0        TB-11280    408         2     106          1   408.3000     1460
# 1        TB-11280     27         1      13          1    27.0900     1416
# 2        TB-11280    301         1       9          1   301.7700      869
# 3        TB-11280    197         1      96          1   197.9400      288
# 4        TB-11280    134         1      12          1   134.1600      288
# 5        TB-11280     27         1      10          1    27.0900      288
# 6        TB-11280     23         2      10          1    23.4600      288
# 7        TB-11280      9         1       2          1     9.2400      288
# 8        TB-11280     59         2     -73          1    59.1600      743
# 9        TB-11280      6         1      -3          1     6.7560      743
# 10       TB-11280    156         1     -39          1   156.4560      165
# Out:
# Customer_ID    object
# Profit          int64
# Frequency       int64
# Monetary        int64
# Recency         int64
# label          object
# dtype: object

# %%
df_t.head()
# Out:
#   Customer_ID  Profit  Frequency  Monetary  Recency label
# 0    AA-10315     435         42     13747        8     2
# 1    AA-10375     666         42      5884        6     2
# 2    AA-10480    1501         38     17695      117     2
# 3    AA-10645    3032         73     15343       26     2
# 4      AA-315     534          8      2243        2     0

# %%
sns.pairplot(df_t[['Profit','Frequency','Monetary','Recency','label']], hue='label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-77-9918cb1f4f35> in <module>
#       2 import pandas as pd
#       3 import seaborn as sns
# ----> 4 sns.pairplot(df_t[['Profit','Frequency','Monetary','Recency','label']], hue='label')
#       5 plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1397                     color = fixed_color
#    1398
# -> 1399                 func(data_k, label=label_k, color=color, **kwargs)
#    1400
#    1401             self._clean_axis(ax)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     207             self._neff = 1/sum(self._weights**2)
#     208
# --> 209         self.set_bandwidth(bw_method=bw_method)
#     210
#     211     def evaluate(self, points):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     563             raise ValueError(msg)
#     564
# --> 565         self._compute_covariance()
#     566
#     567     def _compute_covariance(self):
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     575                                                bias=False,
#     576                                                aweights=self.weights))
# --> 577             self._data_inv_cov = linalg.inv(self._data_covariance)
#     578
#     579         self.covariance = self._data_covariance * self.factor**2
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     977         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     978     if info > 0:
# --> 979         raise LinAlgError("singular matrix")
#     980     if info < 0:
#     981         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x=df_t.Frequency, y=df_t.Profit, hue=df_t.label)

# %%
df_t
# Out:
#              Profit  Frequency     Monetary  Recency  label
# Customer_ID
# AA-10315        435         42  13747.41300        8      1
# AA-10375        666         42   5884.19500        6      1
# AA-10480       1501         38  17695.58978      117      1
# AA-10645       3032         73  15343.89070       26      1
# AA-315          534          8   2243.25600        2      0
# AA-375           75         13    654.49200      181      2
# AA-480          552         10   2063.49300      314      2
# AA-645         -607         18   1968.32400       81      2
# AB-10015       3694         77  20037.49750       16      1
# AB-10060       4496         57  18416.55040       25      1
# AB-10105       6903         62  22966.78000       32      1
# AB-10150       2052         47  13057.29460       22      1
# AB-10165       2313         52  11649.26500       13      1
# AB-10255        -57         53  10786.71640        5      1
# AB-105         -496         15   2156.40000       43      0
# AB-10600        905         38  13318.66310       50      1
# AB-15           957         12   4607.13000      412      2
# AB-150          861          8   3143.88000      398      2
# AB-165          105          8   1399.77600       16      0
# AB-255          797         15   4679.50200       43      0
# AB-60           465         11   1770.22800       35      2
# AB-600          953         26   5408.55000        7      0
# AC-10420        205         40  10607.69470        6      1
# AC-10450       4099         29  16126.39040        5      1
# AC-10615       1139         65  12729.72448        6      1
# AC-10660      -1001         35   6255.61908        2      0
# AC-420          230         21   1689.67500       13      0
# AC-450         -129         10   1026.59700      116      2
# AC-615         -285         18   2298.43200       92      2
# AC-660          722          8   2676.09000      297      2
# ...             ...        ...          ...      ...    ...
# VG-11790         47          7    386.17200      160      2
# VG-11805        140          7   1190.22000      135      2
# VG-21790       -418         43   9908.60650       22      1
# VG-21805       3894         54  22573.37116        2      1
# VM-11685        -98         14    858.97800       13      0
# VM-11835        334          7   1270.41000        8      0
# VM-21685      -1565         54  13708.12232       32      1
# VM-21835        310         29   2621.81700       52      0
# VP-11730       -504          9    432.00000      162      2
# VP-11760        371          9   1615.66200      117      2
# VP-21730       2724         49  11629.26900       40      1
# VP-21760       2000         51  16935.56350       75      1
# VS-11820        124         11   1136.21400      110      2
# VS-21820       1452         29  10275.77500       87      1
# VT-11700        175         11   1271.44200      125      2
# VT-21700        904         61  18099.30610        7      1
# VW-11775        251          9   1253.16600        7      0
# VW-21775         32         57  15785.37740        6      1
# WB-11850       -145          5    182.53200      144      2
# WB-21850       2671         79  16704.66120       20      1
# XP-11865         65          6   1011.79800      160      2
# XP-21865       1219         55  11187.15260       43      1
# YC-11895         20          5    166.29900       99      2
# YC-21895       4303         51  19998.07860        4      1
# YS-11880        356          8   1328.83200        4      0
# YS-21880       3075         54  18703.60600        9      1
# ZC-11910        -15          1      7.17300      200      2
# ZC-21910        443         84  28472.81926        3      1
# ZD-11925        472         18   2951.22600        3      0
# ZD-21925       -287         36   9479.34440        1      0
#
# [1590 rows x 5 columns]
