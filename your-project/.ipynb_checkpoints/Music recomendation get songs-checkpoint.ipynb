# %% [markdown]
# ### Libaries

# %%
import pprint
import sys
import json
import spotipy
import spotipy.util as util
import pprint
import pandas as pd
from pandas.io.json import json_normalize
import math
import time
import numpy as np
sleep_min = 1
sleep_max = 5

# %% [markdown]
# ### Connect to Spotify API
#
# Here we need different parameters to connect to the API,
# we need an OAuth2 authorization but also a Token to get current user data.
#
# The scope is a Spotify parameter to have access to different parts of the API
#
# The Client_Id and Client_Secret are provided by Spotify when creating a 'New App'
# at https://developer.spotify.com/dashboard/applications
#
# The first time it connects OAUTH2 answer a token to a locahost:8080, you have to copy the website link and run the code. This option is not possible under Jupyter notebook so run the file file://../../connect_spotify_api.py and follow the steps.
#
# After the response, it creates a file .cache_['username'] wich will allow access for some time.

# %%
username = 'nerken' # 'incautiouswifi' #some users don't have a name, just an ID
scope = 'user-follow-read,user-follow-modify,user-read-recently-played,user-top-read,user-library-read,user-library-modify,user-read-playback-state,user-read-currently-playing,user-modify-playback-state,playlist-read-collaborative,playlist-modify-private,playlist-modify-public,playlist-read-private,app-remote-control,user-read-email,user-read-private'

client_id = '22e782a724264812b124038bbf783396'
client_secret = '6219554f45764f2cbfe13306ec476f10'
oauth2 = util.oauth2.SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
token = util.prompt_for_user_token(username, scope=scope, client_id='22e782a724264812b124038bbf783396', client_secret='6219554f45764f2cbfe13306ec476f10', redirect_uri='https://localhost:8080')

# %%
# Let's test if we have a OAuth2 and the Token
print(f'The Oauth2 object is: {oauth2} \n')
print(f'The current user token is: {token}')
# Out:
# The Oauth2 object is: <spotipy.oauth2.SpotifyClientCredentials object at 0x000001EA5B8D9148>
#
# The current user token is: BQB6naERgoFKuSoHy2-mrq-MDlmhaZMRT42XTLa5ZtEbBy7MYZy1AatxarUgUfFoxrbVKTERgeaMivD7NgSrcs7u7Qvga7Q31TP4kwcGu9UiT7eubaj35xFzD4CRZ1Nv6uhvSID4UWKqSzXYDJbkYNiXBpZ4gwku6SRG6Nci4LYHZerTRbJvE7bfoJ1teMGxqsFGbhJbNF0Z_5aZURRKre6octmSq28Uzse2tjlNdKIww5VMRRm0tazdMH0XRpwJaurF4DGleEst

# %% [markdown]
# ### Getting the User Data
#
# Here we want to get all the playlist for the current user, and split it between Album, Artist, Playlist, Songs. Since all the data is well structurated on spotify API the process will be from playlist->Album->Artist->Song.
#
# Firstly I will get all the raw data and save it to csv to be able to wrangling it, cleaning it and upload it to a database.

# %%
# open a Spotify connection
sp = spotipy.Spotify(auth=token)

# %%
# let's get user information even we probably not gonna use it
user_data = sp.user(user=username)
json_normalize(user_data,max_level=1)
# Out:
#      display_name                                     href      id  \
# 0  Josep Foradada  https://api.spotify.com/v1/users/nerken  nerken
#
#                                               images  type  \
# 0  [{'height': None, 'url': 'https://scontent.xx....  user
#
#                    uri                 external_urls.spotify followers.href  \
# 0  spotify:user:nerken  https://open.spotify.com/user/nerken           None
#
#    followers.total
# 0               26

# %%
# Get total user playlists
total_user_playlists = json_normalize(sp.user_playlists(user=username,limit=1,offset=0),max_level=0).total[0]

# %%
total_user_playlists
# Out:
# 74

# %%
#generate a function that iterates to get all playlists with a time delay for each request

def get_user_playlists(username,total_user_playlists):
        '''
        Get all playlists from a current user
        '''
        limit = 50 # number of results per request 
        loops = math.ceil(total_user_playlists/limit)
        users_playlists = pd.DataFrame()
        for x in range(loops):
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            results = sp.current_user_playlists(limit=50,offset=0+(x*50))
            for x in range(len(results['items'])):
                a = (json_normalize(results['items'][x]))
                users_playlists = users_playlists.append(a, ignore_index=True)
        return users_playlists

# %%
users_playlists = get_user_playlists(username,total_user_playlists)

# %%
users_playlists.head(5)
# Out:
#    collaborative                                               href  \
# 0           True  https://api.spotify.com/v1/playlists/0ogOkIjBi...
# 1          False  https://api.spotify.com/v1/playlists/3tW0YVAZt...
# 2          False  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 3          False  https://api.spotify.com/v1/playlists/1QxdL1fPW...
# 4          False  https://api.spotify.com/v1/playlists/37i9dQZF1...
#
#                        id                                             images  \
# 0  0ogOkIjBiisl0aqtx53DHY  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 1  3tW0YVAZtrpV0oR7lxQxxy  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 2  37i9dQZF1DWUAZoWydCivZ  [{'height': None, 'url': 'https://pl.scdn.co/i...
# 3  1QxdL1fPW4X4eex4CrFryW  [{'height': None, 'url': 'https://pl.scdn.co/i...
# 4  37i9dQZF1DX8CTD7HWYPDn  [{'height': None, 'url': 'https://pl.scdn.co/i...
#
#                    name primary_color  public  \
# 0  Atún de la Frontera🐟          None   False
# 1        RUMBA CATALANA          None   False
# 2        Positive Vibes          None   False
# 3             Good Mood          None   False
# 4     Canta en la Ducha          None   False
#
#                                          snapshot_id      type  \
# 0  MTQ5LGRiYTMzOGYyN2Q2ZDg1NDlkODRiMmU1YTBjYmMxYz...  playlist
# 1  MjUwLDk3YTk3Zjk0ZDg4ZTY1NjhlNGY0YzQyODNlNGM2ZD...  playlist
# 2  MTU2MzQzMDI2MCwwMDAwMDAzMjAwMDAwMTZjMDNiNDhlZD...  playlist
# 3  ODQwLDE2NDI4YzJhOGM1N2MxZjI1YWZmZGVjMTNhYWI0OT...  playlist
# 4  MTU2NjIyOTIxMCwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMD...  playlist
#
#                                        uri  \
# 0  spotify:playlist:0ogOkIjBiisl0aqtx53DHY
# 1  spotify:playlist:3tW0YVAZtrpV0oR7lxQxxy
# 2  spotify:playlist:37i9dQZF1DWUAZoWydCivZ
# 3  spotify:playlist:1QxdL1fPW4X4eex4CrFryW
# 4  spotify:playlist:37i9dQZF1DX8CTD7HWYPDn
#
#                                external_urls.spotify    owner.display_name  \
# 0  https://open.spotify.com/playlist/0ogOkIjBiisl...  Íngrid Munné Collado
# 1  https://open.spotify.com/playlist/3tW0YVAZtrpV...           joansayeras
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...               Spotify
# 3  https://open.spotify.com/playlist/1QxdL1fPW4X4...        Digster France
# 4  https://open.spotify.com/playlist/37i9dQZF1DX8...               Spotify
#
#                  owner.external_urls.spotify  \
# 0      https://open.spotify.com/user/wobniar
# 1  https://open.spotify.com/user/joansayeras
# 2      https://open.spotify.com/user/spotify
# 3   https://open.spotify.com/user/digster.fr
# 4      https://open.spotify.com/user/spotify
#
#                                      owner.href     owner.id owner.type  \
# 0      https://api.spotify.com/v1/users/wobniar      wobniar       user
# 1  https://api.spotify.com/v1/users/joansayeras  joansayeras       user
# 2      https://api.spotify.com/v1/users/spotify      spotify       user
# 3   https://api.spotify.com/v1/users/digster.fr   digster.fr       user
# 4      https://api.spotify.com/v1/users/spotify      spotify       user
#
#                   owner.uri  \
# 0      spotify:user:wobniar
# 1  spotify:user:joansayeras
# 2      spotify:user:spotify
# 3   spotify:user:digster.fr
# 4      spotify:user:spotify
#
#                                          tracks.href  tracks.total
# 0  https://api.spotify.com/v1/playlists/0ogOkIjBi...           121
# 1  https://api.spotify.com/v1/playlists/3tW0YVAZt...           163
# 2  https://api.spotify.com/v1/playlists/37i9dQZF1...            50
# 3  https://api.spotify.com/v1/playlists/1QxdL1fPW...           101
# 4  https://api.spotify.com/v1/playlists/37i9dQZF1...            50

# %%
users_playlists.groupby(['owner.id'])['tracks.total'].sum()
# Out:
# owner.id
# 1133054025                   50
# cabina6                     150
# csuberviola                 615
# cuthbertgrau               1222
# diestro                     136
# digster.fr                  101
# elcarlesdesiempre           270
# elenanogues                 243
# elmon                      1098
# jahamer27                    73
# joansayeras                 163
# jrufi91                      92
# martychristian             1831
# mejoresplaylistsspotify     106
# nerken                     1913
# pcnaimad                     91
# phobox                      452
# pixelmaniatik               329
# sonymusicentertainment       96
# spotify                     305
# tonijohan                  4390
# travismartin86             2995
# tv3alaxarxa                 221
# wobniar                     121
# ànima                        40
# Name: tracks.total, dtype: int64

# %%
# remove all playlists that the owner is not the 'username'

owner_id = users_playlists[(users_playlists['owner.id'] != username)].index
 
users_playlists.drop(owner_id , inplace=True)

# %%
users_playlists['tracks.total'].sum()
# Out:
# 1913

# %%
user_playlists = users_playlists.reset_index(drop=True)

# %%
user_playlists
# Out:
#     collaborative                                               href  \
# 0           False  https://api.spotify.com/v1/playlists/3ypuzkCtK...
# 1           False  https://api.spotify.com/v1/playlists/03aHsHAJv...
# 2           False  https://api.spotify.com/v1/playlists/6uzNpJIT2...
# 3           False  https://api.spotify.com/v1/playlists/7uuoJ3glh...
# 4           False  https://api.spotify.com/v1/playlists/3adsbUvUt...
# 5           False  https://api.spotify.com/v1/playlists/5mLQ2pzeG...
# 6            True  https://api.spotify.com/v1/playlists/7nW9BlocQ...
# 7           False  https://api.spotify.com/v1/playlists/28RqwFckD...
# 8           False  https://api.spotify.com/v1/playlists/17G5Gs4hj...
# 9           False  https://api.spotify.com/v1/playlists/4uBsB8Vrl...
# 10          False  https://api.spotify.com/v1/playlists/7sKPU13Af...
# 11          False  https://api.spotify.com/v1/playlists/7bsAR19p7...
# 12          False  https://api.spotify.com/v1/playlists/0K6zEWxGi...
# 13          False  https://api.spotify.com/v1/playlists/3fFvSuiHK...
# 14          False  https://api.spotify.com/v1/playlists/6rcoq12Ri...
# 15          False  https://api.spotify.com/v1/playlists/64JY1fITM...
# 16          False  https://api.spotify.com/v1/playlists/6F0bDRMil...
# 17          False  https://api.spotify.com/v1/playlists/4YMWrJrGA...
# 18          False  https://api.spotify.com/v1/playlists/7EHzH8D5F...
# 19          False  https://api.spotify.com/v1/playlists/0tiNVBKGt...
# 20          False  https://api.spotify.com/v1/playlists/41qf7DQAs...
# 21          False  https://api.spotify.com/v1/playlists/2SScimtgT...
# 22          False  https://api.spotify.com/v1/playlists/1t4E2pmmU...
# 23          False  https://api.spotify.com/v1/playlists/5Z8VUi5qQ...
# 24          False  https://api.spotify.com/v1/playlists/0EwEbOTco...
# 25          False  https://api.spotify.com/v1/playlists/6NkUTDW3O...
# 26          False  https://api.spotify.com/v1/playlists/5bI2Q0cfK...
# 27          False  https://api.spotify.com/v1/playlists/6Vc5br1vN...
# 28          False  https://api.spotify.com/v1/playlists/1wrqSkZXU...
# 29          False  https://api.spotify.com/v1/playlists/2VW0MLYsZ...
# 30          False  https://api.spotify.com/v1/playlists/6S6YOHxtl...
# 31          False  https://api.spotify.com/v1/playlists/5arziQ4hg...
# 32          False  https://api.spotify.com/v1/playlists/2DM514FHH...
# 33          False  https://api.spotify.com/v1/playlists/0Kz18Qq6b...
# 34          False  https://api.spotify.com/v1/playlists/7vHRwRtvm...
# 35          False  https://api.spotify.com/v1/playlists/5aMcG4sVM...
# 36          False  https://api.spotify.com/v1/playlists/2jig3jDOL...
# 37          False  https://api.spotify.com/v1/playlists/3hS8GwHWU...
# 38          False  https://api.spotify.com/v1/playlists/2wZ4hdXDK...
# 39          False  https://api.spotify.com/v1/playlists/26yOZG9Eu...
# 40          False  https://api.spotify.com/v1/playlists/7LqEvFlU6...
# 41          False  https://api.spotify.com/v1/playlists/5LR210vwh...
# 42          False  https://api.spotify.com/v1/playlists/7AbQaavvw...
# 43          False  https://api.spotify.com/v1/playlists/5FAkbyeCq...
#
#                         id                                             images  \
# 0   3ypuzkCtKGOQ0Y63x295Jx  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 1   03aHsHAJv9vHySsb82CYB7  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 2   6uzNpJIT2e1cOHVhYdg8Kr  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   7uuoJ3glhbTcKGo4PzqQu8  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   3adsbUvUtQcVmqSdCpRNIH  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   5mLQ2pzeGmEwuc7NFrsmp6  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 6   7nW9BlocQCzpeLwufiJ4RJ  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 7   28RqwFckD9aUZqyksBUCKw  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 8   17G5Gs4hjwytQt3l6mkph2  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 9   4uBsB8VrlhHkN9Zazl0hO8  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 10  7sKPU13AfyV0yN60OYFELl  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11  7bsAR19p7zO45OpIpiCqQB  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 12  0K6zEWxGiCGZLejWC5RjLh  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 13  3fFvSuiHKyiNHj4myybmRM  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  6rcoq12RiupfqlzZK8rEX5  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  64JY1fITMumLMHvbjyhYHS  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 16  6F0bDRMilmN0VdkEtsS0Cz  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  4YMWrJrGAyW04sfFwE3sc4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  7EHzH8D5Fv7EWf76tDTSvH  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  0tiNVBKGtCjcH37FsQsaIg  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 20  41qf7DQAsri9nLj6pVWpOt  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 21  2SScimtgToL52F3sxoFIX6  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 22  1t4E2pmmUPII9lPWzYkLFU  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 23  5Z8VUi5qQUVkO1HzuZXUq9  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 24  0EwEbOTcoueyXQl1Et4Or6  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 25  6NkUTDW3ONdztqUQs7YeNM  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 26  5bI2Q0cfKkAtsuSt9jUeZc  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 27  6Vc5br1vN5YUwjGd6FxIMp  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 28  1wrqSkZXURdcTk0X4BO0bP  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 29  2VW0MLYsZGkVE101NEyrdc  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30  6S6YOHxtlap5BcYdl8MSZn  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 31  5arziQ4hgOyxgWqNikNVvO  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 32  2DM514FHHlHf64BLAzoIWe  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 33  0Kz18Qq6boSucTkU8R2aaF  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 34  7vHRwRtvmggt50qUnnHeaD  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 35  5aMcG4sVMmkV1u3YC63hMQ  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 36  2jig3jDOLAamg7rauyYbsW  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 37  3hS8GwHWUUGI9bMAeLlzLh  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 38  2wZ4hdXDK7A4PWxvdWZaAs  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 39  26yOZG9EufjUlGvl9zE1Fv  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 40  7LqEvFlU62PeN9Ey2GFQ1a  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 41  5LR210vwhwJxrJWBGxTzMh  [{'height': 640, 'url': 'https://mosaic.scdn.c...
# 42  7AbQaavvwWs13zH2XMxUrZ  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 43  5FAkbyeCqjinjYqfbERDYa  [{'height': 640, 'url': 'https://mosaic.scdn.c...
#
#                                                  name primary_color  public  \
# 0       Various Artists – Electro Swing Fever, Vol. 3          None    True
# 1                                        Bishop Allen          None    True
# 2                                                 ONE          None    True
# 3     Various Artists – Música Clássica: Mais Famosas          None    True
# 4                                         Nice COVERS          None    True
# 5                                                  FB          None    True
# 6                                        New Playlist          None   False
# 7                                            Reggeton          None    True
# 8                                       Ramon Mirabet          None    True
# 9                                       Josep Francès          None    True
# 10  Lang Lang – The 50 Greatest Piano Pieces by La...          None    True
# 11                                               50's          None    True
# 12                                          Favoritos          None   False
# 13                                     Classica Josep          None    True
# 14                       The Crab Apples – Right Here          None    True
# 15                                         Bon rotllo          None    True
# 16                      Various Artists – Summer Jazz          None    True
# 17                                        Lisa Ekdahl          None    True
# 18                                            Stromae          None    True
# 19                                              EDITS          None    True
# 20                                               HITS          None    True
# 21       Various Artists – Top 50 Acoustic Cover Hits          None    True
# 22                                                New          None    True
# 23                                     Caravan Palace          None    True
# 24  London Philharmonic Orchestra – The 50 Greates...          None    True
# 25                                   Feel This Moment          None    True
# 26                               Blaumut - El Turista          None    True
# 27                 Nyandú - L'origen de les absències          None    True
# 28        The Free Fall Band – Elephants Never Forget          None    True
# 29                                      Manos de Topo          None    True
# 30                            La Pegatina – Xapomelön          None    True
# 31                        iaia, 4t1a i roger margarit          None    True
# 32                                          Si de nit          None    True
# 33                                      Nerken's Hits          None    True
# 34                                           Catalana          None   False
# 35                                            Spanish          None    True
# 36  Various Artists [Artist] – 100 Classical Favou...          None    True
# 37                 Mine – Un brindis pel nen androide          None    True
# 38          Various Artists – 100 Best Opera Classics          None    True
# 39                                            Running          None    True
# 40                             17 Hippies – El Dorado          None    True
# 41                 The BEST BRITISH songs of all time          None    True
# 42     Volbeat – Live From Beyond Hell / Above Heaven          None    True
# 43                                            Elektro          None    True
#
#                                           snapshot_id      type  \
# 0   Miw1ZmMyMjZlYzlhYTVmZWViZDA1NWIzNzVmMzdjNzc0ZT...  playlist
# 1   OCwxOTkxZmQ5MzM0NzUyMjc3NTFjYjI3NzI4MTVhNzIyZW...  playlist
# 2   MyxlYjI0MGViNWE2MjAzMGRmOWEwOThkYWY3NjNhYmJmNz...  playlist
# 3   MyxkZGQ1YjI1MmJkZmIxNmYzZDBkMzU4MTRiZDg1YTM5MG...  playlist
# 4   Myw2Y2FmN2FjNmYzODA1NGU4YjQzMTk2MWYwMTA1N2JlYW...  playlist
# 5   ODksY2UyNjhkYjgwYjk2MDc4MTNlZjBiMmJmNjg0Njg1NT...  playlist
# 6   NCxmMWNiZjM2MmIzNzViZjViOTE1OTE4N2RhMjQxODVlMz...  playlist
# 7   Niw1OWJmYWRkNjJhYzgxNjg4NTFhYTY2MDM5OTYwNTExZW...  playlist
# 8   NSxiZGZlMGQzN2YzZTZlM2UzZjNhMjRlMDA2NDY0OWVlMz...  playlist
# 9   OCw0MDM3OGY5MWNmMWUwYmY5NjhhNDA1N2MzYWM3NWJiZW...  playlist
# 10  MyxmYTFlZjdmODVmYzkxMWE3NGZiNWRjODI0OThjZTZlYT...  playlist
# 11  MjYsZWE1ZjdjODIwZjA3Nzg3NmU1ZDRkNWYwNmMxZGQwNG...  playlist
# 12  MyxiZDIzZDI4MmRlMGEyOTA3OTc5MTRiYjdmYjM3ZDQ4N2...  playlist
# 13  NSw0NjE1ZjFlOThhOTIyMmZiYTg4ZWZmYTc5OTVkMDlmM2...  playlist
# 14  Myw1ZjRhMDBkMzkwNGQ3MTg1MTk3NmFiYTk2MTQwM2JkM2...  playlist
# 15  MjAsMmQwZjQzMTM3YWQ2MWZjNGY1OWE0YmQyNmUyZTA5Zm...  playlist
# 16  MyxmNTU0MTBlZWQzNGIzZGE1NjJmNTYwODE2N2VhMmMxYz...  playlist
# 17  MywxYmI4ZjcxZmZkNTJlYmI5YTQxNTE3M2VjNzQwMzQ5Yz...  playlist
# 18  NCwyYjE2ODcxMGI5MzRiYTUzMDY0NDU3YzBmZjhkZTdiNj...  playlist
# 19  Nyw4Mjg1NzBiZjM2NWM5ZjUzYTYyM2JmNzU1MjUwMDAwZm...  playlist
# 20  MTYsOTQzZWVhOWI0ZWMwZWMwN2YxMTA0M2I2MmYyNGJhZT...  playlist
# 21  MixmM2U4NzQ1ODBiN2I0Y2ViMjNjZTc2Y2RiZjY4ZTgxZj...  playlist
# 22  NixiZDM0NzZhZmU0ZWQ1MGNiY2Y1ZjAyM2RjOTQzODlhNj...  playlist
# 23  NCxlOWE4Yzk2MTQ1NDk3YWU3NDAxOGY1Y2E1YjNlOTk5OD...  playlist
# 24  Miw2MmY0YmMxMzM2MTY0ODM3ZDkxY2YwOGUwZDk0ZWMwOW...  playlist
# 25  Miw4NGI3ZDZlNDczYzFhYmUxYWIwN2Q1YWFlZDk3YzdhOW...  playlist
# 26  Miw2OTM2ZWFlN2Q0ZjdkNmFmYjE4ZGM2YWIzYTNhMjE4YW...  playlist
# 27  MixjNGZiODU1YWM0YTdhNGY1MmFhNjM2MzZkYWFkODgzZj...  playlist
# 28  NCxmNzExYWYyYTVkODMzZGVmOWE5MTQ1ZDQyZDc5YTYzNm...  playlist
# 29  Niw2YzExNmJlMDk5NmUyYjFmNDlkNmM5Mjc2NTIzYmU3Yj...  playlist
# 30  Miw4YWZkMGEyMWYxM2ZjNTM5NjY5ZWYwZGFkOTZiMzg4Ym...  playlist
# 31  NSxmZGJlMGQwNWE3ZmU5NjY2MDVhNzYyZGI3MjRlNjViYW...  playlist
# 32  Miw2ODRiNjdlZGFmOTVmNGZjMDVkYTU2YmUzZjg2YTM5N2...  playlist
# 33  NDY0LGNhMmUxNGZhYTA1Y2EwMzY4MzQ4NjQwZWVkMGVmMj...  playlist
# 34  NjMsN2ZjNjUwOGE4MjIyMDY4MDA5NzY5YmMzYWY0MDViMW...  playlist
# 35  NzgsMTc5ZWNkYmIwZGU3MmQzYzgxYzM3YTQ3MzhiMWM4ND...  playlist
# 36  NixhZjAxYzhhNGE0OTEyM2M5N2I2ZGM5ODY1Yjk1M2JhYm...  playlist
# 37  MixjOWYzNWFlMTZhNzcyMTNlOTM2N2M5NWJiYzFmN2NiOD...  playlist
# 38  MixhNjg4MjVmMmM4M2M5NWM2Mjk1MDgxM2IwMDNkODQzYW...  playlist
# 39  NzUsMjUwODYzNGNmMTkyMzkwNDM4OTdmMDJmOGRjMmE2ZD...  playlist
# 40  MixjZDQ5MjU5YjhhYmMxMmZlZWZlNjdlNDZmYzMyMDBlNT...  playlist
# 41  MiwwZDk5MDZlZDFjYzM0YzI5NTJhMzUzYTZkMTdmN2FjND...  playlist
# 42  NSw4OGM1ZDhlYmZmMjczYWY0NzBmYzdlOTEwZTFjOTdlMz...  playlist
# 43  MTUsMWY4MjgzZTRmMjA4YTE5NmZjMjQ2Y2QyNjIzNjQxZG...  playlist
#
#                                         uri  \
# 0   spotify:playlist:3ypuzkCtKGOQ0Y63x295Jx
# 1   spotify:playlist:03aHsHAJv9vHySsb82CYB7
# 2   spotify:playlist:6uzNpJIT2e1cOHVhYdg8Kr
# 3   spotify:playlist:7uuoJ3glhbTcKGo4PzqQu8
# 4   spotify:playlist:3adsbUvUtQcVmqSdCpRNIH
# 5   spotify:playlist:5mLQ2pzeGmEwuc7NFrsmp6
# 6   spotify:playlist:7nW9BlocQCzpeLwufiJ4RJ
# 7   spotify:playlist:28RqwFckD9aUZqyksBUCKw
# 8   spotify:playlist:17G5Gs4hjwytQt3l6mkph2
# 9   spotify:playlist:4uBsB8VrlhHkN9Zazl0hO8
# 10  spotify:playlist:7sKPU13AfyV0yN60OYFELl
# 11  spotify:playlist:7bsAR19p7zO45OpIpiCqQB
# 12  spotify:playlist:0K6zEWxGiCGZLejWC5RjLh
# 13  spotify:playlist:3fFvSuiHKyiNHj4myybmRM
# 14  spotify:playlist:6rcoq12RiupfqlzZK8rEX5
# 15  spotify:playlist:64JY1fITMumLMHvbjyhYHS
# 16  spotify:playlist:6F0bDRMilmN0VdkEtsS0Cz
# 17  spotify:playlist:4YMWrJrGAyW04sfFwE3sc4
# 18  spotify:playlist:7EHzH8D5Fv7EWf76tDTSvH
# 19  spotify:playlist:0tiNVBKGtCjcH37FsQsaIg
# 20  spotify:playlist:41qf7DQAsri9nLj6pVWpOt
# 21  spotify:playlist:2SScimtgToL52F3sxoFIX6
# 22  spotify:playlist:1t4E2pmmUPII9lPWzYkLFU
# 23  spotify:playlist:5Z8VUi5qQUVkO1HzuZXUq9
# 24  spotify:playlist:0EwEbOTcoueyXQl1Et4Or6
# 25  spotify:playlist:6NkUTDW3ONdztqUQs7YeNM
# 26  spotify:playlist:5bI2Q0cfKkAtsuSt9jUeZc
# 27  spotify:playlist:6Vc5br1vN5YUwjGd6FxIMp
# 28  spotify:playlist:1wrqSkZXURdcTk0X4BO0bP
# 29  spotify:playlist:2VW0MLYsZGkVE101NEyrdc
# 30  spotify:playlist:6S6YOHxtlap5BcYdl8MSZn
# 31  spotify:playlist:5arziQ4hgOyxgWqNikNVvO
# 32  spotify:playlist:2DM514FHHlHf64BLAzoIWe
# 33  spotify:playlist:0Kz18Qq6boSucTkU8R2aaF
# 34  spotify:playlist:7vHRwRtvmggt50qUnnHeaD
# 35  spotify:playlist:5aMcG4sVMmkV1u3YC63hMQ
# 36  spotify:playlist:2jig3jDOLAamg7rauyYbsW
# 37  spotify:playlist:3hS8GwHWUUGI9bMAeLlzLh
# 38  spotify:playlist:2wZ4hdXDK7A4PWxvdWZaAs
# 39  spotify:playlist:26yOZG9EufjUlGvl9zE1Fv
# 40  spotify:playlist:7LqEvFlU62PeN9Ey2GFQ1a
# 41  spotify:playlist:5LR210vwhwJxrJWBGxTzMh
# 42  spotify:playlist:7AbQaavvwWs13zH2XMxUrZ
# 43  spotify:playlist:5FAkbyeCqjinjYqfbERDYa
#
#                                 external_urls.spotify owner.display_name  \
# 0   https://open.spotify.com/playlist/3ypuzkCtKGOQ...     Josep Foradada
# 1   https://open.spotify.com/playlist/03aHsHAJv9vH...     Josep Foradada
# 2   https://open.spotify.com/playlist/6uzNpJIT2e1c...     Josep Foradada
# 3   https://open.spotify.com/playlist/7uuoJ3glhbTc...     Josep Foradada
# 4   https://open.spotify.com/playlist/3adsbUvUtQcV...     Josep Foradada
# 5   https://open.spotify.com/playlist/5mLQ2pzeGmEw...     Josep Foradada
# 6   https://open.spotify.com/playlist/7nW9BlocQCzp...     Josep Foradada
# 7   https://open.spotify.com/playlist/28RqwFckD9aU...     Josep Foradada
# 8   https://open.spotify.com/playlist/17G5Gs4hjwyt...     Josep Foradada
# 9   https://open.spotify.com/playlist/4uBsB8VrlhHk...     Josep Foradada
# 10  https://open.spotify.com/playlist/7sKPU13AfyV0...     Josep Foradada
# 11  https://open.spotify.com/playlist/7bsAR19p7zO4...     Josep Foradada
# 12  https://open.spotify.com/playlist/0K6zEWxGiCGZ...     Josep Foradada
# 13  https://open.spotify.com/playlist/3fFvSuiHKyiN...     Josep Foradada
# 14  https://open.spotify.com/playlist/6rcoq12Riupf...     Josep Foradada
# 15  https://open.spotify.com/playlist/64JY1fITMumL...     Josep Foradada
# 16  https://open.spotify.com/playlist/6F0bDRMilmN0...     Josep Foradada
# 17  https://open.spotify.com/playlist/4YMWrJrGAyW0...     Josep Foradada
# 18  https://open.spotify.com/playlist/7EHzH8D5Fv7E...     Josep Foradada
# 19  https://open.spotify.com/playlist/0tiNVBKGtCjc...     Josep Foradada
# 20  https://open.spotify.com/playlist/41qf7DQAsri9...     Josep Foradada
# 21  https://open.spotify.com/playlist/2SScimtgToL5...     Josep Foradada
# 22  https://open.spotify.com/playlist/1t4E2pmmUPII...     Josep Foradada
# 23  https://open.spotify.com/playlist/5Z8VUi5qQUVk...     Josep Foradada
# 24  https://open.spotify.com/playlist/0EwEbOTcouey...     Josep Foradada
# 25  https://open.spotify.com/playlist/6NkUTDW3ONdz...     Josep Foradada
# 26  https://open.spotify.com/playlist/5bI2Q0cfKkAt...     Josep Foradada
# 27  https://open.spotify.com/playlist/6Vc5br1vN5YU...     Josep Foradada
# 28  https://open.spotify.com/playlist/1wrqSkZXURdc...     Josep Foradada
# 29  https://open.spotify.com/playlist/2VW0MLYsZGkV...     Josep Foradada
# 30  https://open.spotify.com/playlist/6S6YOHxtlap5...     Josep Foradada
# 31  https://open.spotify.com/playlist/5arziQ4hgOyx...     Josep Foradada
# 32  https://open.spotify.com/playlist/2DM514FHHlHf...     Josep Foradada
# 33  https://open.spotify.com/playlist/0Kz18Qq6boSu...     Josep Foradada
# 34  https://open.spotify.com/playlist/7vHRwRtvmggt...     Josep Foradada
# 35  https://open.spotify.com/playlist/5aMcG4sVMmkV...     Josep Foradada
# 36  https://open.spotify.com/playlist/2jig3jDOLAam...     Josep Foradada
# 37  https://open.spotify.com/playlist/3hS8GwHWUUGI...     Josep Foradada
# 38  https://open.spotify.com/playlist/2wZ4hdXDK7A4...     Josep Foradada
# 39  https://open.spotify.com/playlist/26yOZG9EufjU...     Josep Foradada
# 40  https://open.spotify.com/playlist/7LqEvFlU62Pe...     Josep Foradada
# 41  https://open.spotify.com/playlist/5LR210vwhwJx...     Josep Foradada
# 42  https://open.spotify.com/playlist/7AbQaavvwWs1...     Josep Foradada
# 43  https://open.spotify.com/playlist/5FAkbyeCqjin...     Josep Foradada
#
#              owner.external_urls.spotify  \
# 0   https://open.spotify.com/user/nerken
# 1   https://open.spotify.com/user/nerken
# 2   https://open.spotify.com/user/nerken
# 3   https://open.spotify.com/user/nerken
# 4   https://open.spotify.com/user/nerken
# 5   https://open.spotify.com/user/nerken
# 6   https://open.spotify.com/user/nerken
# 7   https://open.spotify.com/user/nerken
# 8   https://open.spotify.com/user/nerken
# 9   https://open.spotify.com/user/nerken
# 10  https://open.spotify.com/user/nerken
# 11  https://open.spotify.com/user/nerken
# 12  https://open.spotify.com/user/nerken
# 13  https://open.spotify.com/user/nerken
# 14  https://open.spotify.com/user/nerken
# 15  https://open.spotify.com/user/nerken
# 16  https://open.spotify.com/user/nerken
# 17  https://open.spotify.com/user/nerken
# 18  https://open.spotify.com/user/nerken
# 19  https://open.spotify.com/user/nerken
# 20  https://open.spotify.com/user/nerken
# 21  https://open.spotify.com/user/nerken
# 22  https://open.spotify.com/user/nerken
# 23  https://open.spotify.com/user/nerken
# 24  https://open.spotify.com/user/nerken
# 25  https://open.spotify.com/user/nerken
# 26  https://open.spotify.com/user/nerken
# 27  https://open.spotify.com/user/nerken
# 28  https://open.spotify.com/user/nerken
# 29  https://open.spotify.com/user/nerken
# 30  https://open.spotify.com/user/nerken
# 31  https://open.spotify.com/user/nerken
# 32  https://open.spotify.com/user/nerken
# 33  https://open.spotify.com/user/nerken
# 34  https://open.spotify.com/user/nerken
# 35  https://open.spotify.com/user/nerken
# 36  https://open.spotify.com/user/nerken
# 37  https://open.spotify.com/user/nerken
# 38  https://open.spotify.com/user/nerken
# 39  https://open.spotify.com/user/nerken
# 40  https://open.spotify.com/user/nerken
# 41  https://open.spotify.com/user/nerken
# 42  https://open.spotify.com/user/nerken
# 43  https://open.spotify.com/user/nerken
#
#                                  owner.href owner.id owner.type  \
# 0   https://api.spotify.com/v1/users/nerken   nerken       user
# 1   https://api.spotify.com/v1/users/nerken   nerken       user
# 2   https://api.spotify.com/v1/users/nerken   nerken       user
# 3   https://api.spotify.com/v1/users/nerken   nerken       user
# 4   https://api.spotify.com/v1/users/nerken   nerken       user
# 5   https://api.spotify.com/v1/users/nerken   nerken       user
# 6   https://api.spotify.com/v1/users/nerken   nerken       user
# 7   https://api.spotify.com/v1/users/nerken   nerken       user
# 8   https://api.spotify.com/v1/users/nerken   nerken       user
# 9   https://api.spotify.com/v1/users/nerken   nerken       user
# 10  https://api.spotify.com/v1/users/nerken   nerken       user
# 11  https://api.spotify.com/v1/users/nerken   nerken       user
# 12  https://api.spotify.com/v1/users/nerken   nerken       user
# 13  https://api.spotify.com/v1/users/nerken   nerken       user
# 14  https://api.spotify.com/v1/users/nerken   nerken       user
# 15  https://api.spotify.com/v1/users/nerken   nerken       user
# 16  https://api.spotify.com/v1/users/nerken   nerken       user
# 17  https://api.spotify.com/v1/users/nerken   nerken       user
# 18  https://api.spotify.com/v1/users/nerken   nerken       user
# 19  https://api.spotify.com/v1/users/nerken   nerken       user
# 20  https://api.spotify.com/v1/users/nerken   nerken       user
# 21  https://api.spotify.com/v1/users/nerken   nerken       user
# 22  https://api.spotify.com/v1/users/nerken   nerken       user
# 23  https://api.spotify.com/v1/users/nerken   nerken       user
# 24  https://api.spotify.com/v1/users/nerken   nerken       user
# 25  https://api.spotify.com/v1/users/nerken   nerken       user
# 26  https://api.spotify.com/v1/users/nerken   nerken       user
# 27  https://api.spotify.com/v1/users/nerken   nerken       user
# 28  https://api.spotify.com/v1/users/nerken   nerken       user
# 29  https://api.spotify.com/v1/users/nerken   nerken       user
# 30  https://api.spotify.com/v1/users/nerken   nerken       user
# 31  https://api.spotify.com/v1/users/nerken   nerken       user
# 32  https://api.spotify.com/v1/users/nerken   nerken       user
# 33  https://api.spotify.com/v1/users/nerken   nerken       user
# 34  https://api.spotify.com/v1/users/nerken   nerken       user
# 35  https://api.spotify.com/v1/users/nerken   nerken       user
# 36  https://api.spotify.com/v1/users/nerken   nerken       user
# 37  https://api.spotify.com/v1/users/nerken   nerken       user
# 38  https://api.spotify.com/v1/users/nerken   nerken       user
# 39  https://api.spotify.com/v1/users/nerken   nerken       user
# 40  https://api.spotify.com/v1/users/nerken   nerken       user
# 41  https://api.spotify.com/v1/users/nerken   nerken       user
# 42  https://api.spotify.com/v1/users/nerken   nerken       user
# 43  https://api.spotify.com/v1/users/nerken   nerken       user
#
#               owner.uri                                        tracks.href  \
# 0   spotify:user:nerken  https://api.spotify.com/v1/playlists/3ypuzkCtK...
# 1   spotify:user:nerken  https://api.spotify.com/v1/playlists/03aHsHAJv...
# 2   spotify:user:nerken  https://api.spotify.com/v1/playlists/6uzNpJIT2...
# 3   spotify:user:nerken  https://api.spotify.com/v1/playlists/7uuoJ3glh...
# 4   spotify:user:nerken  https://api.spotify.com/v1/playlists/3adsbUvUt...
# 5   spotify:user:nerken  https://api.spotify.com/v1/playlists/5mLQ2pzeG...
# 6   spotify:user:nerken  https://api.spotify.com/v1/playlists/7nW9BlocQ...
# 7   spotify:user:nerken  https://api.spotify.com/v1/playlists/28RqwFckD...
# 8   spotify:user:nerken  https://api.spotify.com/v1/playlists/17G5Gs4hj...
# 9   spotify:user:nerken  https://api.spotify.com/v1/playlists/4uBsB8Vrl...
# 10  spotify:user:nerken  https://api.spotify.com/v1/playlists/7sKPU13Af...
# 11  spotify:user:nerken  https://api.spotify.com/v1/playlists/7bsAR19p7...
# 12  spotify:user:nerken  https://api.spotify.com/v1/playlists/0K6zEWxGi...
# 13  spotify:user:nerken  https://api.spotify.com/v1/playlists/3fFvSuiHK...
# 14  spotify:user:nerken  https://api.spotify.com/v1/playlists/6rcoq12Ri...
# 15  spotify:user:nerken  https://api.spotify.com/v1/playlists/64JY1fITM...
# 16  spotify:user:nerken  https://api.spotify.com/v1/playlists/6F0bDRMil...
# 17  spotify:user:nerken  https://api.spotify.com/v1/playlists/4YMWrJrGA...
# 18  spotify:user:nerken  https://api.spotify.com/v1/playlists/7EHzH8D5F...
# 19  spotify:user:nerken  https://api.spotify.com/v1/playlists/0tiNVBKGt...
# 20  spotify:user:nerken  https://api.spotify.com/v1/playlists/41qf7DQAs...
# 21  spotify:user:nerken  https://api.spotify.com/v1/playlists/2SScimtgT...
# 22  spotify:user:nerken  https://api.spotify.com/v1/playlists/1t4E2pmmU...
# 23  spotify:user:nerken  https://api.spotify.com/v1/playlists/5Z8VUi5qQ...
# 24  spotify:user:nerken  https://api.spotify.com/v1/playlists/0EwEbOTco...
# 25  spotify:user:nerken  https://api.spotify.com/v1/playlists/6NkUTDW3O...
# 26  spotify:user:nerken  https://api.spotify.com/v1/playlists/5bI2Q0cfK...
# 27  spotify:user:nerken  https://api.spotify.com/v1/playlists/6Vc5br1vN...
# 28  spotify:user:nerken  https://api.spotify.com/v1/playlists/1wrqSkZXU...
# 29  spotify:user:nerken  https://api.spotify.com/v1/playlists/2VW0MLYsZ...
# 30  spotify:user:nerken  https://api.spotify.com/v1/playlists/6S6YOHxtl...
# 31  spotify:user:nerken  https://api.spotify.com/v1/playlists/5arziQ4hg...
# 32  spotify:user:nerken  https://api.spotify.com/v1/playlists/2DM514FHH...
# 33  spotify:user:nerken  https://api.spotify.com/v1/playlists/0Kz18Qq6b...
# 34  spotify:user:nerken  https://api.spotify.com/v1/playlists/7vHRwRtvm...
# 35  spotify:user:nerken  https://api.spotify.com/v1/playlists/5aMcG4sVM...
# 36  spotify:user:nerken  https://api.spotify.com/v1/playlists/2jig3jDOL...
# 37  spotify:user:nerken  https://api.spotify.com/v1/playlists/3hS8GwHWU...
# 38  spotify:user:nerken  https://api.spotify.com/v1/playlists/2wZ4hdXDK...
# 39  spotify:user:nerken  https://api.spotify.com/v1/playlists/26yOZG9Eu...
# 40  spotify:user:nerken  https://api.spotify.com/v1/playlists/7LqEvFlU6...
# 41  spotify:user:nerken  https://api.spotify.com/v1/playlists/5LR210vwh...
# 42  spotify:user:nerken  https://api.spotify.com/v1/playlists/7AbQaavvw...
# 43  spotify:user:nerken  https://api.spotify.com/v1/playlists/5FAkbyeCq...
#
#     tracks.total
# 0             60
# 1             85
# 2              1
# 3             50
# 4              1
# 5             81
# 6             77
# 7              4
# 8             29
# 9              4
# 10            50
# 11            22
# 12             9
# 13             2
# 14            14
# 15            15
# 16            19
# 17            10
# 18            25
# 19             5
# 20            12
# 21            50
# 22             3
# 23            29
# 24            50
# 25             1
# 26            12
# 27            12
# 28            10
# 29            33
# 30            21
# 31            36
# 32             1
# 33           459
# 34            94
# 35            69
# 36           200
# 37            12
# 38           100
# 39             3
# 40            12
# 41           101
# 42            19
# 43            11

# %%
user_playlists['id'][0]
# Out:
# '3ypuzkCtKGOQ0Y63x295Jx'

# %%
try:
    a = sp.user_playlist_tracks(user=username,playlist_id='03aHsHAJv9vHySsb82CYB7',limit=1,offset=0)
except:
    oauth2 = util.oauth2.SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
    token = util.prompt_for_user_token(username, scope=scope, client_id='22e782a724264812b124038bbf783396', client_secret='6219554f45764f2cbfe13306ec476f10', redirect_uri='https://localhost:8080')
    sp = spotipy.Spotify(auth=token)
    a = sp.user_playlist_tracks(user=username,playlist_id='03aHsHAJv9vHySsb82CYB7',limit=1,offset=0)

# %%
a.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
pd.Series(a)
# Out:
# href        https://api.spotify.com/v1/playlists/03aHsHAJv...
# items       [{'added_at': '2017-03-29T18:14:26Z', 'added_b...
# limit                                                       1
# next        https://api.spotify.com/v1/playlists/03aHsHAJv...
# offset                                                      0
# previous                                                 None
# total                                                      85
# dtype: object

# %%
json_normalize(a)
# Out:
#                                                 href  \
# 0  https://api.spotify.com/v1/playlists/03aHsHAJv...
#
#                                                items  limit  \
# 0  [{'added_at': '2017-03-29T18:14:26Z', 'added_b...      1
#
#                                                 next  offset previous  total
# 0  https://api.spotify.com/v1/playlists/03aHsHAJv...       0     None     85

# %%
a
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/03aHsHAJv9vHySsb82CYB7/tracks?offset=0&limit=1',
#  'items': [{'added_at': '2017-03-29T18:14:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/nerken'},
#     'href': 'https://api.spotify.com/v1/users/nerken',
#     'id': 'nerken',
#     'type': 'user',
#     'uri': 'spotify:user:nerken'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rE9FxgMGmsZ8Cg4AeOavJ'},
#        'href': 'https://api.spotify.com/v1/artists/5rE9FxgMGmsZ8Cg4AeOavJ',
#        'id': '5rE9FxgMGmsZ8Cg4AeOavJ',
#        'name': 'Bishop Allen',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rE9FxgMGmsZ8Cg4AeOavJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1D4pWDyvBQeq4x4UKTVvuI'},
#      'href': 'https://api.spotify.com/v1/albums/1D4pWDyvBQeq4x4UKTVvuI',
#      'id': '1D4pWDyvBQeq4x4UKTVvuI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/6ce0d60b930b8c1525d8df7223d40ab7895f5632',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/95d7a96e58b7062ba25f93fa8620305bdc1a8118',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/a6eeb74b9668d47d5a9924da3682911bb2597125',
#        'width': 64}],
#      'name': 'Charm School',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:1D4pWDyvBQeq4x4UKTVvuI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rE9FxgMGmsZ8Cg4AeOavJ'},
#       'href': 'https://api.spotify.com/v1/artists/5rE9FxgMGmsZ8Cg4AeOavJ',
#       'id': '5rE9FxgMGmsZ8Cg4AeOavJ',
#       'name': 'Bishop Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rE9FxgMGmsZ8Cg4AeOavJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 127666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm20322359'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7c1QnSNfgHPLgyqUcdE1Il'},
#     'href': 'https://api.spotify.com/v1/tracks/7c1QnSNfgHPLgyqUcdE1Il',
#     'id': '7c1QnSNfgHPLgyqUcdE1Il',
#     'is_local': False,
#     'name': 'Charm School',
#     'popularity': 10,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8ae40ed9c2ee702d1b395d129e2516d70a1ac374?cid=22e782a724264812b124038bbf783396',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7c1QnSNfgHPLgyqUcdE1Il'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 1,
#  'next': 'https://api.spotify.com/v1/playlists/03aHsHAJv9vHySsb82CYB7/tracks?offset=1&limit=1',
#  'offset': 0,
#  'previous': None,
#  'total': 85}

# %%
tracks = pd.DataFrame(json_normalize(a['items'],max_level=2))

# %%
# display all columns without jupyter notebook limitation
()
pd.options.display.max_columns = None
display(tracks)
# Out:
#                added_at  is_local primary_color  \
# 0  2017-03-29T18:14:26Z     False          None
#
#          added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/nerken
#
#                              added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/nerken      nerken          user
#
#           added_by.uri track.album.album_type  \
# 0  spotify:user:nerken                  album
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                            track.album.external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1D...
#
#                                     track.album.href          track.album.id  \
# 0  https://api.spotify.com/v1/albums/1D4pWDyvBQeq...  1D4pWDyvBQeq4x4UKTVvuI
#
#                                   track.album.images track.album.name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Charm School
#
#   track.album.release_date track.album.release_date_precision  \
# 0               2003-01-01                                day
#
#    track.album.total_tracks track.album.type  \
# 0                        13            album
#
#                         track.album.uri  \
# 0  spotify:album:1D4pWDyvBQeq4x4UKTVvuI
#
#                                        track.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                              track.available_markets  track.disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                  1
#
#    track.duration_ms  track.episode  track.explicit track.external_ids.isrc  \
# 0             127666          False           False            ushm20322359
#
#                          track.external_urls.spotify  \
# 0  https://open.spotify.com/track/7c1QnSNfgHPLgyq...
#
#                                           track.href                track.id  \
# 0  https://api.spotify.com/v1/tracks/7c1QnSNfgHPL...  7c1QnSNfgHPLgyqUcdE1Il
#
#    track.is_local    track.name  track.popularity  \
# 0           False  Charm School                10
#
#                                    track.preview_url  track.track  \
# 0  https://p.scdn.co/mp3-preview/8ae40ed9c2ee702d...         True
#
#    track.track_number track.type                             track.uri  \
# 0                   1      track  spotify:track:7c1QnSNfgHPLgyqUcdE1Il
#
#   video_thumbnail.url
# 0                None

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 40 columns):
# added_at                              1 non-null object
# is_local                              1 non-null bool
# primary_color                         0 non-null object
# added_by.external_urls.spotify        1 non-null object
# added_by.href                         1 non-null object
# added_by.id                           1 non-null object
# added_by.type                         1 non-null object
# added_by.uri                          1 non-null object
# track.album.album_type                1 non-null object
# track.album.artists                   1 non-null object
# track.album.available_markets         1 non-null object
# track.album.external_urls             1 non-null object
# track.album.href                      1 non-null object
# track.album.id                        1 non-null object
# track.album.images                    1 non-null object
# track.album.name                      1 non-null object
# track.album.release_date              1 non-null object
# track.album.release_date_precision    1 non-null object
# track.album.total_tracks              1 non-null int64
# track.album.type                      1 non-null object
# track.album.uri                       1 non-null object
# track.artists                         1 non-null object
# track.available_markets               1 non-null object
# track.disc_number                     1 non-null int64
# track.duration_ms                     1 non-null int64
# track.episode                         1 non-null bool
# track.explicit                        1 non-null bool
# track.external_ids.isrc               1 non-null object
# track.external_urls.spotify           1 non-null object
# track.href                            1 non-null object
# track.id                              1 non-null object
# track.is_local                        1 non-null bool
# track.name                            1 non-null object
# track.popularity                      1 non-null int64
# track.preview_url                     1 non-null object
# track.track                           1 non-null bool
# track.track_number                    1 non-null int64
# track.type                            1 non-null object
# track.uri                             1 non-null object
# video_thumbnail.url                   0 non-null object
# dtypes: bool(5), int64(5), object(30)
# memory usage: 413.0+ bytes

# %%
nycphil = (a['items'])
type(nycphil)
nycphil
# Out:
# [{'added_at': '2017-03-29T18:14:26Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/nerken'},
#    'href': 'https://api.spotify.com/v1/users/nerken',
#    'id': 'nerken',
#    'type': 'user',
#    'uri': 'spotify:user:nerken'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rE9FxgMGmsZ8Cg4AeOavJ'},
#       'href': 'https://api.spotify.com/v1/artists/5rE9FxgMGmsZ8Cg4AeOavJ',
#       'id': '5rE9FxgMGmsZ8Cg4AeOavJ',
#       'name': 'Bishop Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rE9FxgMGmsZ8Cg4AeOavJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1D4pWDyvBQeq4x4UKTVvuI'},
#     'href': 'https://api.spotify.com/v1/albums/1D4pWDyvBQeq4x4UKTVvuI',
#     'id': '1D4pWDyvBQeq4x4UKTVvuI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/6ce0d60b930b8c1525d8df7223d40ab7895f5632',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/95d7a96e58b7062ba25f93fa8620305bdc1a8118',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a6eeb74b9668d47d5a9924da3682911bb2597125',
#       'width': 64}],
#     'name': 'Charm School',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1D4pWDyvBQeq4x4UKTVvuI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rE9FxgMGmsZ8Cg4AeOavJ'},
#      'href': 'https://api.spotify.com/v1/artists/5rE9FxgMGmsZ8Cg4AeOavJ',
#      'id': '5rE9FxgMGmsZ8Cg4AeOavJ',
#      'name': 'Bishop Allen',
#      'type': 'artist',
#      'uri': 'spotify:artist:5rE9FxgMGmsZ8Cg4AeOavJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 127666,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'ushm20322359'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7c1QnSNfgHPLgyqUcdE1Il'},
#    'href': 'https://api.spotify.com/v1/tracks/7c1QnSNfgHPLgyqUcdE1Il',
#    'id': '7c1QnSNfgHPLgyqUcdE1Il',
#    'is_local': False,
#    'name': 'Charm School',
#    'popularity': 10,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8ae40ed9c2ee702d1b395d129e2516d70a1ac374?cid=22e782a724264812b124038bbf783396',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7c1QnSNfgHPLgyqUcdE1Il'},
#   'video_thumbnail': {'url': None}}]

# %%
tracks
# Out:
#                added_at  is_local primary_color  \
# 0  2017-03-29T18:14:26Z     False          None
#
#          added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/nerken
#
#                              added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/nerken      nerken          user
#
#           added_by.uri track.album.album_type  \
# 0  spotify:user:nerken                  album
#
#                                  track.album.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                        track.album.available_markets  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                            track.album.external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1D...
#
#                                     track.album.href          track.album.id  \
# 0  https://api.spotify.com/v1/albums/1D4pWDyvBQeq...  1D4pWDyvBQeq4x4UKTVvuI
#
#                                   track.album.images track.album.name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Charm School
#
#   track.album.release_date track.album.release_date_precision  \
# 0               2003-01-01                                day
#
#    track.album.total_tracks track.album.type  \
# 0                        13            album
#
#                         track.album.uri  \
# 0  spotify:album:1D4pWDyvBQeq4x4UKTVvuI
#
#                                        track.artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
#
#                              track.available_markets  track.disc_number  \
# 0  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                  1
#
#    track.duration_ms  track.episode  track.explicit track.external_ids.isrc  \
# 0             127666          False           False            ushm20322359
#
#                          track.external_urls.spotify  \
# 0  https://open.spotify.com/track/7c1QnSNfgHPLgyq...
#
#                                           track.href                track.id  \
# 0  https://api.spotify.com/v1/tracks/7c1QnSNfgHPL...  7c1QnSNfgHPLgyqUcdE1Il
#
#    track.is_local    track.name  track.popularity  \
# 0           False  Charm School                10
#
#                                    track.preview_url  track.track  \
# 0  https://p.scdn.co/mp3-preview/8ae40ed9c2ee702d...         True
#
#    track.track_number track.type                             track.uri  \
# 0                   1      track  spotify:track:7c1QnSNfgHPLgyqUcdE1Il
#
#   video_thumbnail.url
# 0                None

# %%
json_normalize(tracks['track.album.artists'][0]).keys()
# Out:
# Index(['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify'], dtype='object')

# %%
tracks2 = pd.DataFrame(json_normalize(tracks['track.album.artists'][0]))

# %%
tracks2
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/5rE9FxgMGms...  5rE9FxgMGmsZ8Cg4AeOavJ
#
#            name    type                                    uri  \
# 0  Bishop Allen  artist  spotify:artist:5rE9FxgMGmsZ8Cg4AeOavJ
#
#                                external_urls.spotify
# 0  https://open.spotify.com/artist/5rE9FxgMGmsZ8C...

# %%
def get_user_songs(username,user_playlists):
    '''
    Get all songs for all the playlists
    '''
    user_songs = pd.DataFrame()
    user_songs_raw = pd.DataFrame()
    total_num_of_tracks = 0
    user_songs['playlist_id'] = 1
    for x in range(len(user_playlists)):
        total_num_of_tracks += user_playlists['tracks.total'][x]
        playlist_id = user_playlists['id'][x]
        print(f'Playlist number {x+1}, id: {playlist_id}')
        limit = 100 # number of results per request 
        loops = math.ceil(user_playlists['tracks.total'][x]/limit)
        actual_num_of_rows = user_songs.shape[0]
        for x in range(loops):
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            try:
                results = sp.user_playlist_tracks(user=username,playlist_id=playlist_id,limit=100,offset=0+(x*100))
            except:
                oauth2 = util.oauth2.SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
                token = util.prompt_for_user_token(username, scope=scope, client_id='22e782a724264812b124038bbf783396', client_secret='6219554f45764f2cbfe13306ec476f10', redirect_uri='https://localhost:8080')
                sp = spotipy.Spotify(auth=token)
                results = sp.user_playlist_tracks(user=username,playlist_id=playlist_id,limit=100,offset=0+(x*100))
            for x in range(len(results['items'])):
                a = (json_normalize(results['items'][x]))
                user_songs = user_songs.append(a, ignore_index=True)
        print(actual_num_of_rows)
        print(total_num_of_tracks)
        
        user_songs['playlist_id'].iloc[actual_num_of_rows:(total_num_of_tracks-1)] = playlist_id
    return user_songs #user_songs_raw

# %%
user_songs = get_user_songs(username,user_playlists)
# Out:
# Playlist number 1, id: 3ypuzkCtKGOQ0Y63x295Jx
# 0
# 60
# Playlist number 2, id: 03aHsHAJv9vHySsb82CYB7
# 60
# 145

# %%
user_songs
# Out:
#                  added_at        added_by.external_urls.spotify  \
# 0    2018-10-24T14:52:55Z  https://open.spotify.com/user/nerken
# 1    2018-10-24T14:52:55Z  https://open.spotify.com/user/nerken
# 2    2018-10-24T14:52:55Z  https://open.spotify.com/user/nerken
# 3    2018-10-24T14:52:55Z  https://open.spotify.com/user/nerken
# 4    2018-10-24T14:52:55Z  https://open.spotify.com/user/nerken
# ..                    ...                                   ...
# 140  2017-03-29T18:14:50Z  https://open.spotify.com/user/nerken
# 141  2017-03-29T18:14:50Z  https://open.spotify.com/user/nerken
# 142  2017-03-29T18:14:50Z  https://open.spotify.com/user/nerken
# 143  2017-03-29T18:14:50Z  https://open.spotify.com/user/nerken
# 144  2017-03-29T18:14:50Z  https://open.spotify.com/user/nerken
#
#                                added_by.href added_by.id added_by.type  \
# 0    https://api.spotify.com/v1/users/nerken      nerken          user
# 1    https://api.spotify.com/v1/users/nerken      nerken          user
# 2    https://api.spotify.com/v1/users/nerken      nerken          user
# 3    https://api.spotify.com/v1/users/nerken      nerken          user
# 4    https://api.spotify.com/v1/users/nerken      nerken          user
# ..                                       ...         ...           ...
# 140  https://api.spotify.com/v1/users/nerken      nerken          user
# 141  https://api.spotify.com/v1/users/nerken      nerken          user
# 142  https://api.spotify.com/v1/users/nerken      nerken          user
# 143  https://api.spotify.com/v1/users/nerken      nerken          user
# 144  https://api.spotify.com/v1/users/nerken      nerken          user
#
#             added_by.uri is_local             playlist_id primary_color  \
# 0    spotify:user:nerken    False  3ypuzkCtKGOQ0Y63x295Jx          None
# 1    spotify:user:nerken    False  3ypuzkCtKGOQ0Y63x295Jx          None
# 2    spotify:user:nerken    False  3ypuzkCtKGOQ0Y63x295Jx          None
# 3    spotify:user:nerken    False  3ypuzkCtKGOQ0Y63x295Jx          None
# 4    spotify:user:nerken    False  3ypuzkCtKGOQ0Y63x295Jx          None
# ..                   ...      ...                     ...           ...
# 140  spotify:user:nerken    False  03aHsHAJv9vHySsb82CYB7          None
# 141  spotify:user:nerken    False  03aHsHAJv9vHySsb82CYB7          None
# 142  spotify:user:nerken    False  03aHsHAJv9vHySsb82CYB7          None
# 143  spotify:user:nerken    False  03aHsHAJv9vHySsb82CYB7          None
# 144  spotify:user:nerken    False                     NaN          None
#
#     track.album.album_type                                track.album.artists  \
# 0              compilation  [{'external_urls': {'spotify': 'https://open.s...
# 1              compilation  [{'external_urls': {'spotify': 'https://open.s...
# 2              compilation  [{'external_urls': {'spotify': 'https://open.s...
# 3              compilation  [{'external_urls': {'spotify': 'https://open.s...
# 4              compilation  [{'external_urls': {'spotify': 'https://open.s...
# ..                     ...                                                ...
# 140                  album  [{'external_urls': {'spotify': 'https://open.s...
# 141                  album  [{'external_urls': {'spotify': 'https://open.s...
# 142                  album  [{'external_urls': {'spotify': 'https://open.s...
# 143                  album  [{'external_urls': {'spotify': 'https://open.s...
# 144                  album  [{'external_urls': {'spotify': 'https://open.s...
#
#                          track.album.available_markets  \
# 0    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 1    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 2    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 3    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 4    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# ..                                                 ...
# 140  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 141  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 142  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 143  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# 144  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
#
#                      track.album.external_urls.spotify  \
# 0    https://open.spotify.com/album/5VOdrHq3pi0FTHQ...
# 1    https://open.spotify.com/album/5VOdrHq3pi0FTHQ...
# 2    https://open.spotify.com/album/5VOdrHq3pi0FTHQ...
# 3    https://open.spotify.com/album/5VOdrHq3pi0FTHQ...
# 4    https://open.spotify.com/album/5VOdrHq3pi0FTHQ...
# ..                                                 ...
# 140  https://open.spotify.com/album/18s9wbg4ak8syac...
# 141  https://open.spotify.com/album/18s9wbg4ak8syac...
# 142  https://open.spotify.com/album/18s9wbg4ak8syac...
# 143  https://open.spotify.com/album/18s9wbg4ak8syac...
# 144  https://open.spotify.com/album/18s9wbg4ak8syac...
#
#                                       track.album.href  \
# 0    https://api.spotify.com/v1/albums/5VOdrHq3pi0F...
# 1    https://api.spotify.com/v1/albums/5VOdrHq3pi0F...
# 2    https://api.spotify.com/v1/albums/5VOdrHq3pi0F...
# 3    https://api.spotify.com/v1/albums/5VOdrHq3pi0F...
# 4    https://api.spotify.com/v1/albums/5VOdrHq3pi0F...
# ..                                                 ...
# 140  https://api.spotify.com/v1/albums/18s9wbg4ak8s...
# 141  https://api.spotify.com/v1/albums/18s9wbg4ak8s...
# 142  https://api.spotify.com/v1/albums/18s9wbg4ak8s...
# 143  https://api.spotify.com/v1/albums/18s9wbg4ak8s...
# 144  https://api.spotify.com/v1/albums/18s9wbg4ak8s...
#
#              track.album.id  \
# 0    5VOdrHq3pi0FTHQZtBaj7V
# 1    5VOdrHq3pi0FTHQZtBaj7V
# 2    5VOdrHq3pi0FTHQZtBaj7V
# 3    5VOdrHq3pi0FTHQZtBaj7V
# 4    5VOdrHq3pi0FTHQZtBaj7V
# ..                      ...
# 140  18s9wbg4ak8syacjEwU4vq
# 141  18s9wbg4ak8syacjEwU4vq
# 142  18s9wbg4ak8syacjEwU4vq
# 143  18s9wbg4ak8syacjEwU4vq
# 144  18s9wbg4ak8syacjEwU4vq
#
#                                     track.album.images  \
# 0    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4    [{'height': 640, 'url': 'https://i.scdn.co/ima...
# ..                                                 ...
# 140  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 141  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 142  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 143  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 144  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                 track.album.name track.album.release_date  \
# 0    Electro Swing Fever, Vol. 3               2014-02-17
# 1    Electro Swing Fever, Vol. 3               2014-02-17
# 2    Electro Swing Fever, Vol. 3               2014-02-17
# 3    Electro Swing Fever, Vol. 3               2014-02-17
# 4    Electro Swing Fever, Vol. 3               2014-02-17
# ..                           ...                      ...
# 140                   Lights Out               2014-08-19
# 141                   Lights Out               2014-08-19
# 142                   Lights Out               2014-08-19
# 143                   Lights Out               2014-08-19
# 144                   Lights Out               2014-08-19
#
#     track.album.release_date_precision  track.album.total_tracks  \
# 0                                  day                      60.0
# 1                                  day                      60.0
# 2                                  day                      60.0
# 3                                  day                      60.0
# 4                                  day                      60.0
# ..                                 ...                       ...
# 140                                day                      12.0
# 141                                day                      12.0
# 142                                day                      12.0
# 143                                day                      12.0
# 144                                day                      12.0
#
#     track.album.type                       track.album.uri  \
# 0              album  spotify:album:5VOdrHq3pi0FTHQZtBaj7V
# 1              album  spotify:album:5VOdrHq3pi0FTHQZtBaj7V
# 2              album  spotify:album:5VOdrHq3pi0FTHQZtBaj7V
# 3              album  spotify:album:5VOdrHq3pi0FTHQZtBaj7V
# 4              album  spotify:album:5VOdrHq3pi0FTHQZtBaj7V
# ..               ...                                   ...
# 140            album  spotify:album:18s9wbg4ak8syacjEwU4vq
# 141            album  spotify:album:18s9wbg4ak8syacjEwU4vq
# 142            album  spotify:album:18s9wbg4ak8syacjEwU4vq
# 143            album  spotify:album:18s9wbg4ak8syacjEwU4vq
# 144            album  spotify:album:18s9wbg4ak8syacjEwU4vq
#
#                                          track.artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 140  [{'external_urls': {'spotify': 'https://open.s...
# 141  [{'external_urls': {'spotify': 'https://open.s...
# 142  [{'external_urls': {'spotify': 'https://open.s...
# 143  [{'external_urls': {'spotify': 'https://open.s...
# 144  [{'external_urls': {'spotify': 'https://open.s...
#
#                                track.available_markets  track.disc_number  \
# 0    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 1                                                   []                1.0
# 2                                                   []                1.0
# 3    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 4    [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# ..                                                 ...                ...
# 140  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 141  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 142  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 143  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
# 144  [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...                1.0
#
#      track.duration_ms track.episode track.explicit track.external_ids.isrc  \
# 0             181000.0         False          False            FR6F31402670
# 1             265093.0         False          False            FR6F31402680
# 2             305280.0         False          False            FR6F31402690
# 3             204026.0         False          False            FR6F31402700
# 4             341493.0         False          False            FR6F31402710
# ..                 ...           ...            ...                     ...
# 140           255440.0         False          False            USJ5G1405308
# 141           262760.0         False          False            USJ5G1405309
# 142           229106.0         False          False            USJ5G1405310
# 143           190893.0         False          False            USJ5G1405311
# 144           174106.0         False          False            USJ5G1405312
#
#                            track.external_urls.spotify  \
# 0    https://open.spotify.com/track/3wD62ofDBqgeJSW...
# 1    https://open.spotify.com/track/14EeHJP2ZhOqabZ...
# 2    https://open.spotify.com/track/4iGiK3PUx1r9G6N...
# 3    https://open.spotify.com/track/2KTHFxwHv1eUUAL...
# 4    https://open.spotify.com/track/2I13jeL6QfdArAh...
# ..                                                 ...
# 140  https://open.spotify.com/track/1ojb5Y366uFsUaM...
# 141  https://open.spotify.com/track/46fQLOxb2T3nHJQ...
# 142  https://open.spotify.com/track/0P6MilAWnmv8sm2...
# 143  https://open.spotify.com/track/2jHGAHrJBN20EeO...
# 144  https://open.spotify.com/track/6fV2G0trm9bVSvq...
#
#                                             track.href  \
# 0    https://api.spotify.com/v1/tracks/3wD62ofDBqge...
# 1    https://api.spotify.com/v1/tracks/14EeHJP2ZhOq...
# 2    https://api.spotify.com/v1/tracks/4iGiK3PUx1r9...
# 3    https://api.spotify.com/v1/tracks/2KTHFxwHv1eU...
# 4    https://api.spotify.com/v1/tracks/2I13jeL6QfdA...
# ..                                                 ...
# 140  https://api.spotify.com/v1/tracks/1ojb5Y366uFs...
# 141  https://api.spotify.com/v1/tracks/46fQLOxb2T3n...
# 142  https://api.spotify.com/v1/tracks/0P6MilAWnmv8...
# 143  https://api.spotify.com/v1/tracks/2jHGAHrJBN20...
# 144  https://api.spotify.com/v1/tracks/6fV2G0trm9bV...
#
#                    track.id track.is_local  \
# 0    3wD62ofDBqgeJSW2u7WKil          False
# 1    14EeHJP2ZhOqabZgCAF27r          False
# 2    4iGiK3PUx1r9G6N3vkQERe          False
# 3    2KTHFxwHv1eUUALTx7uBei          False
# 4    2I13jeL6QfdArAhpqUzFSr          False
# ..                      ...            ...
# 140  1ojb5Y366uFsUaMua89Yrb          False
# 141  46fQLOxb2T3nHJQxmWOrCf          False
# 142  0P6MilAWnmv8sm2On9CO4d          False
# 143  2jHGAHrJBN20EeO05b1ADg          False
# 144  6fV2G0trm9bVSvqhRE6CdQ          False
#
#                                             track.name  track.popularity  \
# 0                      Ragtime Cat (feat. Lilja Bloom)              21.0
# 1                                            Artichaut               0.0
# 2                                           Extra Mile               0.0
# 3                                       AAA (Triple A)              15.0
# 4    The Sound of Swing (Onur Engin Edit) [feat. Al...              13.0
# ..                                                 ...               ...
# 140                                          Good Talk               8.0
# 141                                    Hammer and Nail               6.0
# 142                                       Bread Crumbs               8.0
# 143                                      No Conditions               5.0
# 144                                             Shadow              13.0
#
#                                      track.preview_url track.track  \
# 0    https://p.scdn.co/mp3-preview/973b9b1ff20c6eba...        True
# 1                                                 None        True
# 2                                                 None        True
# 3    https://p.scdn.co/mp3-preview/f4bb734b2c3dfcd7...        True
# 4    https://p.scdn.co/mp3-preview/0be61e8c94449b99...        True
# ..                                                 ...         ...
# 140  https://p.scdn.co/mp3-preview/937df9dc6c1a5362...        True
# 141  https://p.scdn.co/mp3-preview/947786a7846d6c60...        True
# 142  https://p.scdn.co/mp3-preview/9f521086f61899e5...        True
# 143  https://p.scdn.co/mp3-preview/893e3fdd8951e69f...        True
# 144  https://p.scdn.co/mp3-preview/73c85a5a7400b27f...        True
#
#      track.track_number track.type                             track.uri  \
# 0                   1.0      track  spotify:track:3wD62ofDBqgeJSW2u7WKil
# 1                   2.0      track  spotify:track:14EeHJP2ZhOqabZgCAF27r
# 2                   3.0      track  spotify:track:4iGiK3PUx1r9G6N3vkQERe
# 3                   4.0      track  spotify:track:2KTHFxwHv1eUUALTx7uBei
# 4                   5.0      track  spotify:track:2I13jeL6QfdArAhpqUzFSr
# ..                  ...        ...                                   ...
# 140                 8.0      track  spotify:track:1ojb5Y366uFsUaMua89Yrb
# 141                 9.0      track  spotify:track:46fQLOxb2T3nHJQxmWOrCf
# 142                10.0      track  spotify:track:0P6MilAWnmv8sm2On9CO4d
# 143                11.0      track  spotify:track:2jHGAHrJBN20EeO05b1ADg
# 144                12.0      track  spotify:track:6fV2G0trm9bVSvqhRE6CdQ
#
#     video_thumbnail.url
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ..                  ...
# 140                None
# 141                None
# 142                None
# 143                None
# 144                None
#
# [145 rows x 41 columns]

# %%
user_songs.to_csv(username+'_user_songs.csv')
