# %%
import numpy as np
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sqlalchemy import create_engine
import os
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pydot
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
sns.set()

from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs
from mpl_toolkits.mplot3d import Axes3D

# %%
df=pd.read_csv('superstore_dataset2011-2015.csv',encoding= 'unicode_escape')

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# 1   OFF-SU-10000618  Office Supplies     Supplies
# 2  OFF-TEN-10001585  Office Supplies      Storage
# 3   OFF-PA-10001492  Office Supplies        Paper
# 4   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product Name    Sales Quantity Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300        2      0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3      0.1   36.036
# 2      Tenex Box, Single Width   66.120        4      0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5      0.1   37.770
#
#    Shipping Cost  Order Priority
# 0          35.46          Medium
# 1           9.72          Medium
# 2           8.17            High
# 3           4.82            High
# 4           4.70          Medium
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: Sub-Category, dtype: int64

# %%
df.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
df.drop(['Row ID', 'Postal Code', 'Ship Date', 'State'],axis=1, inplace=True)

# %%
df.describe()
# Out:
#               Sales      Quantity      Discount        Profit  Shipping Cost
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.610982      26.375915
# std      487.565361      2.278766      0.212280    174.340972      57.296804
# min        0.444000      1.000000      0.000000  -6599.978000       0.000000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000

# %%
df.head()
# Out:
#           Order ID Order Date       Ship Mode Customer ID    Customer Name  \
# 0     AG-2011-2040   1/1/2011  Standard Class    TB-11280  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  Standard Class    JH-15985      Joseph Holt
# 2     HU-2011-1220   1/1/2011    Second Class      AT-735    Annie Thurman
# 3  IT-2011-3647632   1/1/2011    Second Class    EM-14140     Eugene Moren
# 4    IN-2011-47883   1/1/2011  Standard Class    JH-15985      Joseph Holt
#
#        Segment         City    Country  Market   Region        Product ID  \
# 0     Consumer  Constantine    Algeria  Africa   Africa  OFF-TEN-10000025
# 1     Consumer  Wagga Wagga  Australia    APAC  Oceania   OFF-SU-10000618
# 2     Consumer     Budapest    Hungary    EMEA     EMEA  OFF-TEN-10001585
# 3  Home Office    Stockholm     Sweden      EU    North   OFF-PA-10001492
# 4     Consumer  Wagga Wagga  Australia    APAC  Oceania   FUR-FU-10003447
#
#           Category Sub-Category                 Product Name    Sales  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue  408.300
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed  120.366
# 2  Office Supplies      Storage      Tenex Box, Single Width   66.120
# 3  Office Supplies        Paper  Enermax Note Cards, Premium   44.865
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack  113.670
#
#    Quantity  Discount   Profit  Shipping Cost Order Priority
# 0         2       0.0  106.140          35.46         Medium
# 1         3       0.1   36.036           9.72         Medium
# 2         4       0.0   29.640           8.17           High
# 3         3       0.5  -26.055           4.82           High
# 4         5       0.1   37.770           4.70         Medium

# %%
df.drop(['Order ID','Market','Order Priority'],axis=1, inplace=True)

# %%
df.head()
# Out:
#   Order Date       Ship Mode Customer ID    Customer Name      Segment  \
# 0   1/1/2011  Standard Class    TB-11280  Toby Braunhardt     Consumer
# 1   1/1/2011  Standard Class    JH-15985      Joseph Holt     Consumer
# 2   1/1/2011    Second Class      AT-735    Annie Thurman     Consumer
# 3   1/1/2011    Second Class    EM-14140     Eugene Moren  Home Office
# 4   1/1/2011  Standard Class    JH-15985      Joseph Holt     Consumer
#
#           City    Country   Region        Product ID         Category  \
# 0  Constantine    Algeria   Africa  OFF-TEN-10000025  Office Supplies
# 1  Wagga Wagga  Australia  Oceania   OFF-SU-10000618  Office Supplies
# 2     Budapest    Hungary     EMEA  OFF-TEN-10001585  Office Supplies
# 3    Stockholm     Sweden    North   OFF-PA-10001492  Office Supplies
# 4  Wagga Wagga  Australia  Oceania   FUR-FU-10003447        Furniture
#
#   Sub-Category                 Product Name    Sales  Quantity  Discount  \
# 0      Storage          Tenex Lockers, Blue  408.300         2       0.0
# 1     Supplies     Acme Trimmer, High Speed  120.366         3       0.1
# 2      Storage      Tenex Box, Single Width   66.120         4       0.0
# 3        Paper  Enermax Note Cards, Premium   44.865         3       0.5
# 4  Furnishings   Eldon Light Bulb, Duo Pack  113.670         5       0.1
#
#     Profit  Shipping Cost
# 0  106.140          35.46
# 1   36.036           9.72
# 2   29.640           8.17
# 3  -26.055           4.82
# 4   37.770           4.70

# %%
df.drop(['Shipping Cost', 'Customer Name'],axis=1, inplace=True)

# %%
df.head()
# Out:
#   Order Date       Ship Mode Customer ID      Segment         City    Country  \
# 0   1/1/2011  Standard Class    TB-11280     Consumer  Constantine    Algeria
# 1   1/1/2011  Standard Class    JH-15985     Consumer  Wagga Wagga  Australia
# 2   1/1/2011    Second Class      AT-735     Consumer     Budapest    Hungary
# 3   1/1/2011    Second Class    EM-14140  Home Office    Stockholm     Sweden
# 4   1/1/2011  Standard Class    JH-15985     Consumer  Wagga Wagga  Australia
#
#     Region        Product ID         Category Sub-Category  \
# 0   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3    North   OFF-PA-10001492  Office Supplies        Paper
# 4  Oceania   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product Name    Sales  Quantity  Discount   Profit
# 0          Tenex Lockers, Blue  408.300         2       0.0  106.140
# 1     Acme Trimmer, High Speed  120.366         3       0.1   36.036
# 2      Tenex Box, Single Width   66.120         4       0.0   29.640
# 3  Enermax Note Cards, Premium   44.865         3       0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670         5       0.1   37.770

# %% [markdown]
# ## Data Wrangling each feature

# %%
from datetime import datetime as date
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.columns=['Date', 'Ship_Mode','Customer_ID','Segment','City', 'Country', 'Region', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name', 'Sales','Quantity','Discount','Profit']

# %%
df.head()
# Out:
#         Date       Ship_Mode Customer_ID      Segment         City    Country  \
# 0 2011-01-01  Standard Class    TB-11280     Consumer  Constantine    Algeria
# 1 2011-01-01  Standard Class    JH-15985     Consumer  Wagga Wagga  Australia
# 2 2011-01-01    Second Class      AT-735     Consumer     Budapest    Hungary
# 3 2011-01-01    Second Class    EM-14140  Home Office    Stockholm     Sweden
# 4 2011-01-01  Standard Class    JH-15985     Consumer  Wagga Wagga  Australia
#
#     Region        Product_ID         Category Sub_Category  \
# 0   Africa  OFF-TEN-10000025  Office Supplies      Storage
# 1  Oceania   OFF-SU-10000618  Office Supplies     Supplies
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Storage
# 3    North   OFF-PA-10001492  Office Supplies        Paper
# 4  Oceania   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product_Name    Sales  Quantity  Discount   Profit
# 0          Tenex Lockers, Blue  408.300         2       0.0  106.140
# 1     Acme Trimmer, High Speed  120.366         3       0.1   36.036
# 2      Tenex Box, Single Width   66.120         4       0.0   29.640
# 3  Enermax Note Cards, Premium   44.865         3       0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670         5       0.1   37.770

# %%
df.Ship_Mode.unique()
# Out:
# array(['Standard Class', 'Second Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.drop(['Ship_Mode', 'City', 'Region'],axis=1, inplace=True)

# %%
df.head()
# Out:
#         Date Customer_ID      Segment    Country        Product_ID  \
# 0 2011-01-01    TB-11280     Consumer    Algeria  OFF-TEN-10000025
# 1 2011-01-01    JH-15985     Consumer  Australia   OFF-SU-10000618
# 2 2011-01-01      AT-735     Consumer    Hungary  OFF-TEN-10001585
# 3 2011-01-01    EM-14140  Home Office     Sweden   OFF-PA-10001492
# 4 2011-01-01    JH-15985     Consumer  Australia   FUR-FU-10003447
#
#           Category Sub_Category                 Product_Name    Sales  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue  408.300
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed  120.366
# 2  Office Supplies      Storage      Tenex Box, Single Width   66.120
# 3  Office Supplies        Paper  Enermax Note Cards, Premium   44.865
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack  113.670
#
#    Quantity  Discount   Profit
# 0         2       0.0  106.140
# 1         3       0.1   36.036
# 2         4       0.0   29.640
# 3         3       0.5  -26.055
# 4         5       0.1   37.770

# %%
df.shape
# Out:
# (51290, 12)

# %%
df.groupby('Customer_ID').agg({'Sales':'sum'}).shape
# Out:
# (1590, 1)

# %%
df.Segment.unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df.drop(['Segment'],axis=1, inplace=True)

# %%
df.Date.value_counts()
# Out:
# 2014-06-18    135
# 2014-11-18    127
# 2014-03-09    126
# 2014-11-20    118
# 2014-12-29    116
# 2014-10-12    114
# 2014-11-13    114
# 2014-12-26    110
# 2013-09-20    109
# 2012-11-13    106
# 2014-09-25    104
# 2014-12-11    103
# 2014-11-28    103
# 2014-11-25    103
# 2013-11-11    102
# 2013-06-13    102
# 2014-12-19    101
# 2014-03-12    101
# 2014-09-26    100
# 2014-04-11    100
# 2014-10-22     99
# 2014-12-23     99
# 2014-06-30     99
# 2014-11-21     97
# 2014-11-27     96
# 2014-04-12     96
# 2014-11-19     96
# 2014-09-12     96
# 2013-09-25     95
# 2014-11-26     95
#              ...
# 2013-08-18      2
# 2011-06-03      2
# 2013-10-20      2
# 2011-10-30      2
# 2014-03-23      1
# 2012-02-19      1
# 2012-07-15      1
# 2014-09-02      1
# 2011-05-15      1
# 2014-01-19      1
# 2011-02-27      1
# 2011-07-08      1
# 2012-11-03      1
# 2013-01-13      1
# 2013-10-11      1
# 2012-09-23      1
# 2011-06-02      1
# 2012-07-10      1
# 2012-05-27      1
# 2011-02-01      1
# 2013-06-01      1
# 2013-03-17      1
# 2013-07-07      1
# 2012-10-21      1
# 2012-08-19      1
# 2013-07-21      1
# 2011-06-19      1
# 2011-01-16      1
# 2011-04-24      1
# 2011-02-13      1
# Name: Date, Length: 1430, dtype: int64

# %%
df.Customer_ID.value_counts()
# Out:
# PO-18850    97
# BE-11335    94
# JG-15805    90
# SW-20755    89
# EM-13960    85
# MY-18295    85
# ZC-21910    84
# MP-17965    84
# CK-12205    83
# AF-10870    81
# BW-11110    81
# GH-14425    80
# WB-21850    79
# HM-14860    79
# EM-14140    79
# TP-21130    79
# BF-11170    78
# SC-20380    77
# HG-14845    77
# AB-10015    77
# KH-16690    76
# TS-21610    75
# SE-20110    75
# JK-16090    75
# MF-18250    75
# KA-16525    75
# JE-15715    74
# SD-20485    74
# GT-14710    74
# MA-17560    74
#             ..
# KC-6675      4
# KM-6225      3
# LH-6900      3
# MP-7470      3
# RW-9630      3
# SC-10800     3
# TN-11040     3
# MF-7665      3
# SC-10575     3
# CT-1995      3
# RB-9645      3
# DK-3090      3
# NC-8625      3
# KD-6615      3
# EA-4035      3
# SJ-10500     3
# FH-4350      3
# TT-11070     3
# BD-1500      3
# DB-3405      2
# KD-6270      2
# KB-6585      2
# MG-7875      2
# DK-2985      1
# MG-7650      1
# ME-8010      1
# MG-7890      1
# RC-9825      1
# ZC-11910     1
# BG-1035      1
# Name: Customer_ID, Length: 1590, dtype: int64

# %%
df.Product_ID.value_counts()
# Out:
# OFF-AR-10003651     35
# OFF-AR-10003829     31
# OFF-BI-10002799     30
# OFF-BI-10003708     30
# FUR-CH-10003354     28
# OFF-BI-10002570     27
# OFF-BI-10004140     25
# OFF-BI-10001808     24
# OFF-BI-10003650     24
# OFF-BI-10004632     24
# OFF-BI-10004195     24
# OFF-BI-10000542     23
# OFF-BIN-10002061    23
# OFF-AR-10000091     23
# OFF-STA-10001791    22
# OFF-BI-10001249     22
# OFF-AR-10000110     22
# OFF-BI-10004654     22
# OFF-AR-10004825     22
# OFF-STA-10001747    21
# OFF-AR-10001777     20
# OFF-AR-10001529     20
# OFF-AR-10001228     20
# OFF-FEL-10001865    20
# OFF-BI-10000179     20
# OFF-AR-10000799     20
# OFF-AR-10002805     20
# OFF-AR-10004519     20
# OFF-AR-10000594     20
# OFF-CAR-10001577    20
#                     ..
# OFF-SU-10000079      1
# FUR-CHR-10000888     1
# TEC-PH-10002658      1
# TEC-MA-10003404      1
# OFF-PA-10000655      1
# TEC-MA-10003315      1
# FUR-TA-10001833      1
# TEC-MA-10002055      1
# FUR-TA-10003164      1
# OFF-SU-10004799      1
# FUR-CH-10001805      1
# OFF-BI-10004769      1
# OFF-EN-10002263      1
# FUR-CH-10000689      1
# OFF-XER-10002848     1
# OFF-AR-10000067      1
# OFF-EN-10003885      1
# OFF-ADV-10003196     1
# OFF-EN-10002911      1
# FUR-BO-10003181      1
# OFF-FA-10002708      1
# TEC-CO-10001317      1
# FUR-CH-10004448      1
# OFF-ST-10004341      1
# OFF-FA-10003399      1
# FUR-BO-10004434      1
# OFF-AP-10004350      1
# FUR-FU-10003339      1
# TEC-CO-10003406      1
# FUR-TA-10002931      1
# Name: Product_ID, Length: 10292, dtype: int64

# %%
df.Category.value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: Category, dtype: int64

# %%
df.Sub_Category.value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: Sub_Category, dtype: int64

# %%
df.Product_Name.value_counts()
# Out:
# Staples                                                                      227
# Cardinal Index Tab, Clear                                                     92
# Eldon File Cart, Single Width                                                 90
# Rogers File Cart, Single Width                                                84
# Ibico Index Tab, Clear                                                        83
# Sanford Pencil Sharpener, Water Color                                         80
# Smead File Cart, Single Width                                                 77
# Acco Index Tab, Clear                                                         75
# Stanley Pencil Sharpener, Water Color                                         75
# Avery Index Tab, Clear                                                        74
# Tenex File Cart, Single Width                                                 70
# Stockwell Paper Clips, Assorted Sizes                                         65
# Boston Pencil Sharpener, Water Color                                          59
# Binney & Smith Pencil Sharpener, Water Color                                  55
# Stockwell Thumb Tacks, 12 Pack                                                53
# Avery Binder Covers, Recycled                                                 52
# Wilson Jones 3-Hole Punch, Durable                                            52
# Cardinal Binding Machine, Economy                                             52
# Binney & Smith Sketch Pad, Blue                                               52
# Apple Smart Phone, Full Size                                                  51
# Ibico Binder Covers, Clear                                                    50
# Avery 3-Hole Punch, Recycled                                                  49
# Boston Canvas, Fluorescent                                                    49
# Hon Executive Leather Armchair, Adjustable                                    49
# Cardinal Binding Machine, Clear                                               49
# Fellowes File Cart, Wire Frame                                                49
# Stanley Markers, Water Color                                                  49
# Ibico Binding Machine, Durable                                                49
# Sanford Pencil Sharpener, Easy-Erase                                          49
# Advantus Paper Clips, Assorted Sizes                                          48
#                                                                             ...
# Xerox 1989                                                                     1
# Acco Glide Clips                                                               1
# Penpower WorldCard Pro Card Scanner                                            1
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                             1
# Park Ridge Embossed Executive Business Envelopes                               1
# Pyle PRT45 Retro Home Telephone                                                1
# Chromcraft Training Table, Adjustable Height                                   1
# Holmes Harmony HEPA Air Purifier for 17 x 20 Room                              1
# Okidata B401 Printer                                                           1
# Xerox 20                                                                       1
# Xerox 1926                                                                     1
# RCA ViSYS 25425RE1 Corded phone                                                1
# Barricks Round Table, Rectangular                                              1
# Xerox 1932                                                                     1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream            1
# Hon Round Table, Adjustable Height                                             1
# I.R.I.S IRISCard Anywhere 5 Card Scanner                                       1
# Hunt BOSTON Model 1606 High-Volume Electric Pencil Sharpener, Beige            1
# Xerox WorkCentre 6505DN Laser Multifunction Printer                            1
# Avaya IP Phone 1140E VoIP phone                                                1
# Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops              1
# Newell 342                                                                     1
# Plantronics Single Ear Headset                                                 1
# Panasonic KX MB2061 Multifunction Printer                                      1
# Cisco Desktop Collaboration Experience DX650 IP Video Phone                    1
# Hewlett-Packard Deskjet 3050a All-in-One Color Inkjet Printer                  1
# Cisco SPA 501G IP Phone                                                        1
# Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection      1
# Bevis Coffee Table, with Bottom Storage                                        1
# Sanitaire Vibra Groomer IR Commercial Upright Vacuum, Replacement Belts        1
# Name: Product_Name, Length: 3788, dtype: int64

# %%
len(df.Product_Name.unique())
# Out:
# 3788

# %%
df.head()
# Out:
#         Date Customer_ID    Country        Product_ID         Category  \
# 0 2011-01-01    TB-11280    Algeria  OFF-TEN-10000025  Office Supplies
# 1 2011-01-01    JH-15985  Australia   OFF-SU-10000618  Office Supplies
# 2 2011-01-01      AT-735    Hungary  OFF-TEN-10001585  Office Supplies
# 3 2011-01-01    EM-14140     Sweden   OFF-PA-10001492  Office Supplies
# 4 2011-01-01    JH-15985  Australia   FUR-FU-10003447        Furniture
#
#   Sub_Category                 Product_Name    Sales  Quantity  Discount  \
# 0      Storage          Tenex Lockers, Blue  408.300         2       0.0
# 1     Supplies     Acme Trimmer, High Speed  120.366         3       0.1
# 2      Storage      Tenex Box, Single Width   66.120         4       0.0
# 3        Paper  Enermax Note Cards, Premium   44.865         3       0.5
# 4  Furnishings   Eldon Light Bulb, Duo Pack  113.670         5       0.1
#
#     Profit
# 0  106.140
# 1   36.036
# 2   29.640
# 3  -26.055
# 4   37.770

# %%
df.pivot_table(index=["Product_ID"], values='Sales', columns=['Quantity', 'Discount'], aggfunc={'Sales':'count','Sales':'sum'})
# Out:
# Quantity               1                                                   \
# Discount            0.000 0.002 0.070 0.100 0.150 0.170 0.200 0.202 0.250
# Product_ID
# FUR-ADV-10000002    53.04   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000108    50.01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000183   158.94   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000188    49.98   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000190      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000571   438.96   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000600      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000847    79.29   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001283   111.12   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001440   135.09   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001659    34.20   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001855    79.11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002329      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002601   154.80   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002632      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002889   145.26   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10003147    93.60   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10003326    40.14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004159      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004223    51.39   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004395   168.24   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004499    50.01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004718    20.13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004971    43.65   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000560      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000831   319.77   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000946   480.03   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10001039      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10002449   320.49   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10002710      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# TEC-SHA-10004083      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004151   170.04   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004184   236.40   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004390  1066.68   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004658   124.41   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004874   587.70   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000008    39.96   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000546   111.33   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000699   215.01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000893   298.92   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001232    74.64   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001407   298.08   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001487   115.11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001994   512.34   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002286      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002459      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002497   161.91   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002650      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003065      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003081    72.93   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003330   759.96   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003386   301.89   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003447   254.58   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003550   160.65   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003925   327.24   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004181   600.36   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004536  1207.08   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004542      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004834      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004927      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# Quantity                ...    14                                      \
# Discount         0.270  ... 0.170 0.200 0.270 0.300 0.400 0.470 0.500
# Product_ID              ...
# FUR-ADV-10000002   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000108   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000183   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000188   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000190   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000571   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000600   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10000847   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001283   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001440   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001659   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10001855   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002329   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002601   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002632   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10002889   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10003147   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10003326   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004159   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004223   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004395   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004499   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004718   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-ADV-10004971   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000560   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000831   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10000946   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10001039   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10002449   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# FUR-BAR-10002710   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                ...  ...   ...   ...   ...   ...   ...   ...   ...
# TEC-SHA-10004083   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004151   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004184   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004390   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004658   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-SHA-10004874   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000008   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000546   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000699   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10000893   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001232   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001407   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001487   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10001994   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002286   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002459   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002497   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10002650   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003065   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003081   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003330   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003386   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003447   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003550   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10003925   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004181   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004536   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004542   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004834   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# TEC-STA-10004927   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# Quantity
# Discount            0.600 0.700 0.800
# Product_ID
# FUR-ADV-10000002      NaN   NaN   NaN
# FUR-ADV-10000108      NaN   NaN   NaN
# FUR-ADV-10000183      NaN   NaN   NaN
# FUR-ADV-10000188      NaN   NaN   NaN
# FUR-ADV-10000190      NaN   NaN   NaN
# FUR-ADV-10000571      NaN   NaN   NaN
# FUR-ADV-10000600      NaN   NaN   NaN
# FUR-ADV-10000847      NaN   NaN   NaN
# FUR-ADV-10001283      NaN   NaN   NaN
# FUR-ADV-10001440      NaN   NaN   NaN
# FUR-ADV-10001659      NaN   NaN   NaN
# FUR-ADV-10001855      NaN   NaN   NaN
# FUR-ADV-10002329      NaN   NaN   NaN
# FUR-ADV-10002601      NaN   NaN   NaN
# FUR-ADV-10002632      NaN   NaN   NaN
# FUR-ADV-10002889      NaN   NaN   NaN
# FUR-ADV-10003147      NaN   NaN   NaN
# FUR-ADV-10003326      NaN   NaN   NaN
# FUR-ADV-10004159      NaN   NaN   NaN
# FUR-ADV-10004223      NaN   NaN   NaN
# FUR-ADV-10004395  235.536   NaN   NaN
# FUR-ADV-10004499      NaN   NaN   NaN
# FUR-ADV-10004718      NaN   NaN   NaN
# FUR-ADV-10004971      NaN   NaN   NaN
# FUR-BAR-10000560      NaN   NaN   NaN
# FUR-BAR-10000831      NaN   NaN   NaN
# FUR-BAR-10000946      NaN   NaN   NaN
# FUR-BAR-10001039      NaN   NaN   NaN
# FUR-BAR-10002449      NaN   NaN   NaN
# FUR-BAR-10002710      NaN   NaN   NaN
# ...                   ...   ...   ...
# TEC-SHA-10004083      NaN   NaN   NaN
# TEC-SHA-10004151      NaN   NaN   NaN
# TEC-SHA-10004184      NaN   NaN   NaN
# TEC-SHA-10004390      NaN   NaN   NaN
# TEC-SHA-10004658      NaN   NaN   NaN
# TEC-SHA-10004874      NaN   NaN   NaN
# TEC-STA-10000008      NaN   NaN   NaN
# TEC-STA-10000546      NaN   NaN   NaN
# TEC-STA-10000699      NaN   NaN   NaN
# TEC-STA-10000893      NaN   NaN   NaN
# TEC-STA-10001232      NaN   NaN   NaN
# TEC-STA-10001407      NaN   NaN   NaN
# TEC-STA-10001487      NaN   NaN   NaN
# TEC-STA-10001994      NaN   NaN   NaN
# TEC-STA-10002286      NaN   NaN   NaN
# TEC-STA-10002459      NaN   NaN   NaN
# TEC-STA-10002497      NaN   NaN   NaN
# TEC-STA-10002650      NaN   NaN   NaN
# TEC-STA-10003065      NaN   NaN   NaN
# TEC-STA-10003081      NaN   NaN   NaN
# TEC-STA-10003330      NaN   NaN   NaN
# TEC-STA-10003386      NaN   NaN   NaN
# TEC-STA-10003447      NaN   NaN   NaN
# TEC-STA-10003550      NaN   NaN   NaN
# TEC-STA-10003925      NaN   NaN   NaN
# TEC-STA-10004181      NaN   NaN   NaN
# TEC-STA-10004536      NaN   NaN   NaN
# TEC-STA-10004542      NaN   NaN   NaN
# TEC-STA-10004834      NaN   NaN   NaN
# TEC-STA-10004927      NaN   NaN   NaN
#
# [10292 rows x 293 columns]

# %%
df['Sales_ohne_Discount']=np.where(df.Discount==0, df.Sales, df.Sales/(1-df.Discount))

# %%
df.columns
# Out:
# Index(['Date', 'Customer_ID', 'Country', 'Product_ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.head()
# Out:
#         Date Customer_ID    Country        Product_ID         Category  \
# 0 2011-01-01    TB-11280    Algeria  OFF-TEN-10000025  Office Supplies
# 1 2011-01-01    JH-15985  Australia   OFF-SU-10000618  Office Supplies
# 2 2011-01-01      AT-735    Hungary  OFF-TEN-10001585  Office Supplies
# 3 2011-01-01    EM-14140     Sweden   OFF-PA-10001492  Office Supplies
# 4 2011-01-01    JH-15985  Australia   FUR-FU-10003447        Furniture
#
#   Sub_Category                 Product_Name    Sales  Quantity  Discount  \
# 0      Storage          Tenex Lockers, Blue  408.300         2       0.0
# 1     Supplies     Acme Trimmer, High Speed  120.366         3       0.1
# 2      Storage      Tenex Box, Single Width   66.120         4       0.0
# 3        Paper  Enermax Note Cards, Premium   44.865         3       0.5
# 4  Furnishings   Eldon Light Bulb, Duo Pack  113.670         5       0.1
#
#     Profit  Sales_ohne_Discount
# 0  106.140               408.30
# 1   36.036               133.74
# 2   29.640                66.12
# 3  -26.055                89.73
# 4   37.770               126.30

# %%
df_customers=df.groupby('Customer_ID').agg({'Date':'count','Sales_ohne_Discount':'sum'})

# %%
df_customers
# Out:
#              Date  Sales_ohne_Discount
# Customer_ID
# AA-10315       42             15538.66
# AA-10375       42              7189.69
# AA-10480       38             19596.16
# AA-10645       73             17387.82
# AA-315          8              2499.63
# AA-375         13               744.12
# AA-480         10              2235.63
# AA-645         18              3263.52
# AB-10015       77             23836.95
# AB-10060       57             20941.65
# AB-10105       62             25580.85
# AB-10150       47             14377.72
# AB-10165       52             12772.81
# AB-10255       53             14366.38
# AB-105         15              3298.41
# AB-10600       38             17159.26
# AB-15          12              4607.13
# AB-150          8              3166.29
# AB-165          8              1658.40
# AB-255         15              4828.29
# AB-60          11              2028.33
# AB-600         26              5408.55
# AC-10420       40             12552.28
# AC-10450       29             17385.60
# AC-10615       65             15353.71
# AC-10660       35             10022.14
# AC-420         21              1808.37
# AC-450         10              1399.83
# AC-615         18              3631.68
# AC-660          8              2676.09
# ...           ...                  ...
# VG-11790        7               443.07
# VG-11805        7              1354.02
# VG-21790       43             13549.69
# VG-21805       54             25289.36
# VM-11685       14              1119.33
# VM-11835        7              1270.41
# VM-21685       54             18075.51
# VM-21835       29              2868.36
# VP-11730        9              1112.31
# VP-11760        9              1684.08
# VP-21730       49             12584.95
# VP-21760       51             19937.02
# VS-11820       11              1402.02
# VS-21820       29             11594.87
# VT-11700       11              1411.68
# VT-21700       61             21011.82
# VW-11775        9              1405.41
# VW-21775       57             21017.86
# WB-11850        5               411.51
# WB-21850       79             18948.34
# XP-11865        6              1015.29
# XP-21865       55             13064.63
# YC-11895        5               188.79
# YC-21895       51             22222.28
# YS-11880        8              1337.04
# YS-21880       54             21569.32
# ZC-11910        1                23.91
# ZC-21910       84             38312.71
# ZD-11925       18              3342.72
# ZD-21925       36             11951.03
#
# [1590 rows x 2 columns]

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df_customers)
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss, 'bx-')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
kmeans = KMeans(n_clusters=3).fit(df_customers)
centroids = kmeans.cluster_centers_
df_customers['label'] = kmeans.fit_predict(df_customers)

# %%
plt.scatter(df_customers.Date, df_customers.Sales_ohne_Discount, c= df_customers['label'])
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
